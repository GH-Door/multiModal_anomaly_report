# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import warnings
from pathlib import Path
from collections import Counter, defaultdict
from PIL import Image

warnings.filterwarnings('ignore')

# %%
try:
    import google.colab
    from google.colab import drive

    # !uv pip install anomalib
    # !uv pip install open-clip-torch
    # !uv pip install qwen-vl-utils
    # !uv pip install transformers==4.52.4
    # !uv pip install langchain-chroma langchain-huggingface
    # !uv pip install langchain_community pypdf beautifulsoup4
    # !uv pip install -U bitsandbytes
    # !uv pip install -U torchao

    drive.mount('/content/drive', force_remount=True)

    # Colab Root
    PROJECT_ROOT = Path('/content/drive/Othercomputers/Mac/multiModal_anomaly_report') # 본인 경로 수정: Mac/Window
    DATA_ROOT = PROJECT_ROOT / "dataset" / "MMAD"

except ImportError:

    # Local Root
    PROJECT_ROOT = Path.cwd().parents[1]
    DATA_ROOT = PROJECT_ROOT / "datasets" / "MMAD"

os.chdir(PROJECT_ROOT) # 현재 경로 수정
print(f"Current working directory: {os.getcwd()}")
# Out:
# Using Python 3.12.12 environment at: /usr
# Resolved 98 packages in 1.45s
# Prepared 12 packages in 486ms
# Installed 12 packages in 18ms
#  + anomalib==2.2.0
#  + freia==0.2
#  + imagecodecs==2026.1.14
#  + jsonargparse==4.46.0
#  + kornia==0.8.2
#  + kornia-rs==0.1.10
#  + lightning==2.6.1
#  + lightning-utilities==0.15.2
#  + pytorch-lightning==2.6.1
#  + rich-argparse==1.7.2
#  + torchmetrics==1.8.2
#  + typeshed-client==2.8.2
# Using Python 3.12.12 environment at: /usr
# Resolved 57 packages in 229ms
# Prepared 2 packages in 97ms
# Installed 2 packages in 5ms
#  + ftfy==6.3.1
#  + open-clip-torch==3.2.0
# Using Python 3.12.12 environment at: /usr
# Resolved 9 packages in 164ms
# Prepared 2 packages in 539ms
# Installed 2 packages in 7ms
#  + av==16.1.0
#  + qwen-vl-utils==0.0.14
# Using Python 3.12.12 environment at: /usr
# Resolved 18 packages in 174ms
# Prepared 3 packages in 450ms
# Uninstalled 3 packages in 356ms
# Installed 3 packages in 43ms
#  - huggingface-hub==1.4.1
#  + huggingface-hub==0.36.2
#  - tokenizers==0.22.2
#  + tokenizers==0.21.4
#  - transformers==5.0.0
#  + transformers==4.52.4
# Using Python 3.12.12 environment at: /usr
# Resolved 88 packages in 594ms
# Prepared 14 packages in 531ms
# Installed 14 packages in 20ms
#  + backoff==2.2.1
#  + bcrypt==5.0.0
#  + build==1.4.0
#  + chromadb==1.5.1
#  + durationpy==0.10
#  + kubernetes==35.0.0
#  + langchain-chroma==1.1.0
#  + langchain-huggingface==1.2.0
#  + onnxruntime==1.24.2
#  + opentelemetry-exporter-otlp-proto-grpc==1.38.0
#  + posthog==5.4.0
#  + pybase64==1.4.3
#  + pypika==0.51.1
#  + pyproject-hooks==1.2.0
# Using Python 3.12.12 environment at: /usr
# Resolved 50 packages in 234ms
# Prepared 9 packages in 223ms
# Uninstalled 1 package in 1ms
# Installed 9 packages in 29ms
#  + dataclasses-json==0.6.7
#  + langchain-classic==1.0.1
#  + langchain-community==0.4.1
#  + langchain-text-splitters==1.1.1
#  + marshmallow==3.26.2
#  + mypy-extensions==1.1.0
#  + pypdf==6.7.2
#  - requests==2.32.4
#  + requests==2.32.5
#  + typing-inspect==0.9.0
# Using Python 3.12.12 environment at: /usr
# Resolved 31 packages in 145ms
# Prepared 5 packages in 932ms
# Uninstalled 4 packages in 74ms
# Installed 5 packages in 29ms
#  + bitsandbytes==0.49.2
#  - filelock==3.24.2
#  + filelock==3.24.3
#  - fsspec==2025.3.0
#  + fsspec==2026.2.0
#  - numpy==2.0.2
#  + numpy==2.4.2
#  - setuptools==75.2.0
#  + setuptools==82.0.0
# Using Python 3.12.12 environment at: /usr
# Resolved 1 package in 84ms
# Prepared 1 package in 129ms
# Uninstalled 1 package in 24ms
# Installed 1 package in 11ms
#  - torchao==0.10.0
#  + torchao==0.16.0
# Mounted at /content/drive
# Current working directory: /content/drive/Othercomputers/Mac/multiModal_anomaly_report

# %%
# RAG Dataet path
DOMAIN_KNOWLEDGE_ROOT = DATA_ROOT / "domain_knowledge.json"
PDF_PATH = DATA_ROOT / "packaging_guide.pdf"
CFIA_JSON_PATH = DATA_ROOT / "cfia_knowledge.json"

# %%
from src.rag import Indexer, Retrievers, PDFKnowledgeLoader, JSONKnowledgeLoader

pdf_loader = PDFKnowledgeLoader(pdf_path=PDF_PATH, chunk_size=1000, chunk_overlap=100)
pdf_docs = pdf_loader.load()
print(f"PDF Total: {len(pdf_docs)} chunks")

cfia_docs = JSONKnowledgeLoader(CFIA_JSON_PATH).load()
print(f"CFIA Total: {len(cfia_docs)} docs")
# Out:
# PDF Total: 20 chunks
# CFIA Total: 26 docs

# %%
from src.rag import RAGEvaluator, TEST_QUERIES_MMAD, TEST_QUERIES_EXTERNAL
import shutil

# Config A: JSON only
indexers = Indexer(
    json_path=DOMAIN_KNOWLEDGE_ROOT,
    persist_dir="vectorstore/domain_knowledge"
)
vs_config = indexers.get_or_create()
domain_docs = indexers.load_documents()

# Config B: JSON + PDF
shutil.rmtree("vectorstore/domain_knowledge_pdf", ignore_errors=True)
vs_config_pdf = Indexer(
    persist_dir="vectorstore/domain_knowledge_pdf"
).build_index_from(domain_docs + pdf_docs)

# Config C: JSON + CFIA
shutil.rmtree("vectorstore/domain_knowledge_cfia", ignore_errors=True)
vs_config_cfia = Indexer(
    persist_dir="vectorstore/domain_knowledge_cfia"
).build_index_from(domain_docs + cfia_docs)

# Config D: JSON + PDF + CFIA
shutil.rmtree("vectorstore/domain_knowledge_pdf_cfia", ignore_errors=True)
vs_config_pdf_cfia = Indexer(
    persist_dir="vectorstore/domain_knowledge_pdf_cfia"
).build_index_from(domain_docs + pdf_docs + cfia_docs)

queries = TEST_QUERIES_MMAD + TEST_QUERIES_EXTERNAL

result_config = RAGEvaluator(Retrievers(vs_config)).evaluate(queries, k=3)
result_config_pdf = RAGEvaluator(Retrievers(vs_config_pdf)).evaluate(queries, k=3)
result_config_cfia = RAGEvaluator(Retrievers(vs_config_cfia)).evaluate(queries, k=3)
result_config_pdf_cfia = RAGEvaluator(Retrievers(vs_config_pdf_cfia)).evaluate(queries, k=3)

print(f"{'Config':<12} {'Hit Rate':>10} {'MRR':>10}")
print(f"{'A (JSON)':12} {result_config['hit_rate']:>10.3f} {result_config['mrr']:>10.3f}")
print(f"{'B (+PDF)':12} {result_config_pdf['hit_rate']:>10.3f} {result_config_pdf['mrr']:>10.3f}")
print(f"{'C (+CFIA)':12} {result_config_cfia['hit_rate']:>10.3f} {result_config_cfia['mrr']:>10.3f}")
print(f"{'D (+PDF + CFIA)':12} {result_config_pdf_cfia['hit_rate']:>10.3f} {result_config_pdf_cfia['mrr']:>10.3f}")
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/526 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Config         Hit Rate        MRR
# A (JSON)          0.429      0.429
# B (+PDF)          0.786      0.655
# C (+CFIA)         0.643      0.607
# D (+PDF + CFIA)      0.929      0.798

# %%
from src.utils.loaders import load_json

# setting
# gemma3-4b-int4, gemma3-12b-int4, gemma3-27b-int4
# gemma3-4b-int8, gemma3-12b-int8, gemma3-27b-int8

LLM = "gemma3-12b"
MMAD_CLASS_JSON = DATA_ROOT / "mmad_10classes.json"
OUTPUT_DIR = f"output/{LLM}"
OUTPUT_RAG_ROOT = Path(OUTPUT_DIR) / "rag"

OUTPUT_AD = OUTPUT_RAG_ROOT / "AD"
OUTPUT_ORIGIN = OUTPUT_RAG_ROOT / "original"
OUTPUT_PDF = OUTPUT_RAG_ROOT / "pdf"
OUTPUT_CFIA = OUTPUT_RAG_ROOT / "cfia"
OUTPUT_PDF_CFIA = OUTPUT_RAG_ROOT / "pdf_cfia"
SAMPLE_PER_FOLDER = 3  # 빠른 테스트: 폴더당 3장

# %%
class_10_json = load_json(MMAD_CLASS_JSON)

# With RAG
# !python scripts/run_experiment.py \
    --llm {LLM} \
    --ad-model "patchcore" \
    --rag \
    --data-root {DATA_ROOT} \
    --sample-per-folder {SAMPLE_PER_FOLDER} \
    --output-dir {OUTPUT_ORIGIN} \
    --mmad-json {MMAD_CLASS_JSON} \
    --batch-mode true
# Out:
# Stratified sampling: 3장/폴더, 33폴더
#   Total: 4224 -> Sampled: 99 (normal=30, anomaly=69)
# 2026-02-22 14:41:38.341517: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771771298.365099   45212 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771771298.372990   45212 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771771298.393678   45212 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771771298.393718   45212 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771771298.393721   45212 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771771298.393724   45212 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# RAG enabled: 146 documents indexed
# ============================================================
# MMAD Experiment Runner
# ============================================================
# Experiment:  patchcore_gemma3-12b_1shot_rag
# LLM:         gemma3-12b
# AD model:    patchcore
# RAG:         enabled
# Few-shot:    1
# Template:    Random_template
# Image size:  (384, 384)
# Images:      99 / 4224
# Data root:   /content/drive/Othercomputers/Mac/multiModal_anomaly_report/dataset/MMAD
# Output:      output/gemma3-12b/rag/original/answers_1_shot_gemma3-12b_Random_template_with_patchcore_v0_rag_99img.json
# ============================================================
#
# Filtered MMAD json: 99 images -> output/gemma3-12b/rag/original/_sampled_mmad.json
#
# ============================================================
# Running AD Model Inference
# ============================================================
# Script:       /content/drive/Othercomputers/Mac/multiModal_anomaly_report/scripts/run_ad_inference.py
# Config:       configs/anomaly.yaml
# Checkpoint:   /content/drive/Othercomputers/Mac/multiModal_anomaly_report/dataset/MMAD/checkpoints/patchcore_384
# Version:      v0
# Data root:    /content/drive/Othercomputers/Mac/multiModal_anomaly_report/dataset/MMAD
# MMAD JSON:    output/gemma3-12b/rag/original/_sampled_mmad.json
# Output:       output/gemma3-12b/rag/original/patchcore_predictions.json
#
# Backend: ckpt
# Config: configs/anomaly.yaml
# Output format: report
# Context mode: v2
# Decision rules: configs/ad_policy.json
# Calibration: configs/ad_calibration.json
# Batch size: 8
# IO workers: 8
# Decode reduced: x1
# Save interval: 0
# Profile interval: 128
# Postprocess map: input
# AMP: True
# Keep model cache: False
# Version: v0
# Filters: datasets=['GoodsAD', 'MVTec-LOCO'] categories=['breakfast_box', 'juice_bottle', 'pushpins', 'screw_bag', 'cigarette_box', 'drink_bottle', 'drink_can', 'food_bottle', 'food_box', 'food_package']
# Input size: (384, 384)
# Device: cuda
#
# Loading MMAD data from: output/gemma3-12b/rag/original/_sampled_mmad.json
# Total images to process: 99
# Available models: 10
#   - GoodsAD/cigarette_box
#   - GoodsAD/drink_bottle
#   - GoodsAD/drink_can
#   - GoodsAD/food_bottle
#   - GoodsAD/food_box
#   - GoodsAD/food_package
#   - MVTec-LOCO/breakfast_box
#   - MVTec-LOCO/juice_bottle
#   - MVTec-LOCO/pushpins
#   - MVTec-LOCO/screw_bag
#
# ============================================================
# Running inference
# ============================================================
# Images to process: 99 across 10 categories
#
# [GoodsAD/cigarette_box] Loading model and processing 6 images...
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:213: Attribute 'pre_processor' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['pre_processor'])`.
#   [profile-tail] 6 imgs | read 25.5 ms/img | infer 131.1 ms/img | build 1.3 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.34/0.54 GB
#   Done: 6 images in 0.9s (158ms/img)
#
# [GoodsAD/drink_bottle] Loading model and processing 12 images...
#   [profile-tail] 12 imgs | read 21.0 ms/img | infer 144.0 ms/img | build 1.4 ms/img | save 0.0 ms/img | gpu alloc/reserved 1.07/1.24 GB
#   Done: 12 images in 2.0s (167ms/img)
#
# [GoodsAD/drink_can] Loading model and processing 12 images...
#   [profile-tail] 12 imgs | read 19.6 ms/img | infer 10.7 ms/img | build 1.4 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.41/12.91 GB
#   Done: 12 images in 0.4s (32ms/img)
#
# [GoodsAD/food_bottle] Loading model and processing 12 images...
#   [profile-tail] 12 imgs | read 18.0 ms/img | infer 96.9 ms/img | build 1.3 ms/img | save 0.0 ms/img | gpu alloc/reserved 1.44/34.96 GB
#   Done: 12 images in 1.4s (116ms/img)
#
# [GoodsAD/food_box] Loading model and processing 12 images...
#   [profile-tail] 12 imgs | read 18.0 ms/img | infer 17.4 ms/img | build 1.3 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.67/23.56 GB
#   Done: 12 images in 0.4s (37ms/img)
#
# [GoodsAD/food_package] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 24.5 ms/img | infer 41.0 ms/img | build 1.4 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.81/0.90 GB
#   Done: 9 images in 0.6s (67ms/img)
#
# [MVTec-LOCO/breakfast_box] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 24.3 ms/img | infer 16.2 ms/img | build 1.5 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.56/19.18 GB
#   Done: 9 images in 0.4s (42ms/img)
#
# [MVTec-LOCO/juice_bottle] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 14.5 ms/img | infer 13.9 ms/img | build 1.4 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.54/18.32 GB
#   Done: 9 images in 0.3s (30ms/img)
#
# [MVTec-LOCO/pushpins] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 19.1 ms/img | infer 15.6 ms/img | build 1.2 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.59/20.32 GB
#   Done: 9 images in 0.3s (36ms/img)
#
# [MVTec-LOCO/screw_bag] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 21.3 ms/img | infer 14.8 ms/img | build 1.9 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.58/19.66 GB
#   Done: 9 images in 0.3s (38ms/img)
#
# ============================================================
# Inference complete
# ============================================================
# Processed (this run): 99
# Skipped (no model): 0
# Errors: 0
# Total inference time: 4.93s
# Average: 49.8ms/img
# Output saved to: output/gemma3-12b/rag/original/patchcore_predictions.json
#
# Sample output:
# {
#   "context_version": "ad_context_v2",
#   "image_path": "GoodsAD/cigarette_box/test/good/003_001.jpg",
#   "dataset": "GoodsAD",
#   "category": "cigarette_box",
#   "backend": "ckpt",
#   "anomaly_score": 0.5305,
#   "model_is_anomaly": true,
#   "model_threshold": 0.5,
#   "decision": "normal",
#   "review_needed": false,
#   "decision_confidence": 1.0,
#   "decision_basis": {
#     "center_threshold": 0.5911,
#     "uncertainty_band": 0.02,
#     "score_delta": -0.0606,
#     "used_calibration": true
#   },
#   "class_key": "GoodsAD/cigarette_box",
#   "confidence": {
#     "level": "low",
#     "reliability": "high",
#     "reason": "Score near threshold neighborhood",
#     "reliability_reason": "Policy marks this class as high reliability. Calibrated AUROC=0.910."
#   },
#   "defect_location_raw": {
#     "has_defect": true,
#     "region": "center",
#     "bbox": [
#       1648,
#       461,
#       2242,
#       1930
#     ],
#     "center": [
#       0.648,
#       0.398
#     ],
#     "area_ratio": 0.0133,
#     "confidence": 0.5972
#   },
#   "defect_location": {
#     "has_defect": false,
#     "region": "none",
#     "bbox": null,
#     "center": null,
#     "area_ratio": 0.0,
#     "location_confidence": 0.8587
#   },
#   "use_location_for_report": false,
#   "report_guidance": {
#     "use_ad_for_anomaly_judgement": "high",
#     "use_ad_for_location": "high",
#     "ad_weight": 0.7,
#     "location_confidence": 0.8587,
#     "decision_confidence": 1.0,
#     "instruction": "AD evidence is strong for anomaly existence. Use location hints only if they are consistent with the image.",
#     "reason_codes": [
#       "STRONG_NORMAL_MARGIN"
#     ]
#   },
#   "reason_codes": [
#     "STRONG_NORMAL_MARGIN"
#   ],
#   "map_stats": {
#     "max": 0.5972,
#     "mean": 0.2891,
#     "std": 0.0794
#   }
# }
# Loaded 99 AD predictions
#
# Warming up model (pre-loading weights)...
# Device: NVIDIA A100-SXM4-40GB
# Loading checkpoint shards: 100% 5/5 [00:07<00:00,  1.51s/it]
# Model ready.
#
# Evaluating: 100%|████████████████████████| 99/99 [03:18<00:00,  2.01s/it, acc=76.9%, done=99, err=0]
#
# ============================================================
# Latency by Class
# ============================================================
#   Class                               N   Avg(s)   Total(s)
# ------------------------------------------------------------
#   GoodsAD/cigarette_box               6     4.54      27.22
#   GoodsAD/drink_bottle               12     2.98      35.73
#   GoodsAD/drink_can                  12     1.91      22.95
#   GoodsAD/food_bottle                12     1.63      19.53
#   GoodsAD/food_box                   12     1.64      19.71
#   GoodsAD/food_package                9     1.75      15.76
#   MVTec-LOCO/breakfast_box            9     1.58      14.18
#   MVTec-LOCO/juice_bottle             9     1.54      13.86
#   MVTec-LOCO/pushpins                 9     1.42      12.81
#   MVTec-LOCO/screw_bag                9     1.53      13.78
# ------------------------------------------------------------
#   Overall                            99     2.01      198.5
#
#
# ============================================================
# Calculating Metrics
# ============================================================
# Removed 1 invalid answers
#
# === Accuracy Statistics for answers_1_shot_gemma3-12b_Random_template_with_patchcore_v0_rag_99img.json ===
#
#             Anomaly Detection  Object Classification  Object Analysis  Defect Classification  Defect Localization  Defect Description  Defect Analysis     Recall  Precision         F1    Average
# GoodsAD             54.379085                   80.0        82.222222              76.470588            59.523810           91.428571        93.023256  91.111111  74.545455  82.000000  76.721076
# MVTec-LOCO          75.000000                  100.0        77.142857              87.500000            43.478261           65.217391        80.000000  91.666667  81.481481  86.274510  75.476930
# Average             64.689542                   90.0        79.682540              81.985294            51.501035           78.322981        86.511628  91.388889  78.013468  84.137255  76.099003
#
# === Overall Average ===
# Anomaly Detection        64.689542
# Object Classification    90.000000
# Object Analysis          79.682540
# Defect Classification    81.985294
# Defect Localization      51.501035
# Defect Description       78.322981
# Defect Analysis          86.511628
# Recall                   91.388889
# Precision                78.013468
# F1                       84.137255
# Average                  76.099003
# Name: Average, dtype: float64
#
# Saved accuracy CSV to: output/gemma3-12b/rag/original/answers_1_shot_gemma3-12b_Random_template_with_patchcore_v0_rag_99img_accuracy.csv
#
# Results saved to: output/gemma3-12b/rag/original/answers_1_shot_gemma3-12b_Random_template_with_patchcore_v0_rag_99img.json
# Metadata saved to: output/gemma3-12b/rag/original/answers_1_shot_gemma3-12b_Random_template_with_patchcore_v0_rag_99img.meta.json
# Elapsed: 198.5s

# %%
# json + pdf
# !python scripts/run_experiment.py \
    --llm {LLM} --ad-model "patchcore" --rag \
    --rag-persist-dir vectorstore/domain_knowledge_pdf \
    --data-root {DATA_ROOT} --mmad-json {MMAD_CLASS_JSON} \
    --sample-per-folder {SAMPLE_PER_FOLDER} \
    --output-dir {OUTPUT_PDF} --batch-mode true
# Out:
# Stratified sampling: 3장/폴더, 33폴더
#   Total: 4224 -> Sampled: 99 (normal=30, anomaly=69)
# 2026-02-22 13:33:45.519829: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771767225.544580   26383 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771767225.552651   26383 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771767225.574061   26383 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771767225.574104   26383 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771767225.574108   26383 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771767225.574112   26383 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# RAG enabled: 166 documents indexed
# ============================================================
# MMAD Experiment Runner
# ============================================================
# Experiment:  patchcore_gemma3-12b_1shot_rag
# LLM:         gemma3-12b
# AD model:    patchcore
# RAG:         enabled
# Few-shot:    1
# Template:    Random_template
# Image size:  (384, 384)
# Images:      99 / 4224
# Data root:   /content/drive/Othercomputers/Mac/multiModal_anomaly_report/dataset/MMAD
# Output:      output/gemma3-12b/rag/pdf/answers_1_shot_gemma3-12b_Random_template_with_patchcore_v0_rag_99img.json
# ============================================================
#
# Filtered MMAD json: 99 images -> output/gemma3-12b/rag/pdf/_sampled_mmad.json
#
# ============================================================
# Running AD Model Inference
# ============================================================
# Script:       /content/drive/Othercomputers/Mac/multiModal_anomaly_report/scripts/run_ad_inference.py
# Config:       configs/anomaly.yaml
# Checkpoint:   /content/drive/Othercomputers/Mac/multiModal_anomaly_report/dataset/MMAD/checkpoints/patchcore_384
# Version:      v0
# Data root:    /content/drive/Othercomputers/Mac/multiModal_anomaly_report/dataset/MMAD
# MMAD JSON:    output/gemma3-12b/rag/pdf/_sampled_mmad.json
# Output:       output/gemma3-12b/rag/pdf/patchcore_predictions.json
#
# Backend: ckpt
# Config: configs/anomaly.yaml
# Output format: report
# Context mode: v2
# Decision rules: configs/ad_policy.json
# Calibration: configs/ad_calibration.json
# Batch size: 8
# IO workers: 8
# Decode reduced: x1
# Save interval: 0
# Profile interval: 128
# Postprocess map: input
# AMP: True
# Keep model cache: False
# Version: v0
# Filters: datasets=['GoodsAD', 'MVTec-LOCO'] categories=['breakfast_box', 'juice_bottle', 'pushpins', 'screw_bag', 'cigarette_box', 'drink_bottle', 'drink_can', 'food_bottle', 'food_box', 'food_package']
# Input size: (384, 384)
# Device: cuda
#
# Loading MMAD data from: output/gemma3-12b/rag/pdf/_sampled_mmad.json
# Total images to process: 99
# Available models: 10
#   - GoodsAD/cigarette_box
#   - GoodsAD/drink_bottle
#   - GoodsAD/drink_can
#   - GoodsAD/food_bottle
#   - GoodsAD/food_box
#   - GoodsAD/food_package
#   - MVTec-LOCO/breakfast_box
#   - MVTec-LOCO/juice_bottle
#   - MVTec-LOCO/pushpins
#   - MVTec-LOCO/screw_bag
#
# ============================================================
# Running inference
# ============================================================
# Images to process: 99 across 10 categories
#
# [GoodsAD/cigarette_box] Loading model and processing 6 images...
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:213: Attribute 'pre_processor' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['pre_processor'])`.
#   [profile-tail] 6 imgs | read 32.5 ms/img | infer 130.2 ms/img | build 1.3 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.34/0.54 GB
#   Done: 6 images in 1.0s (164ms/img)
#
# [GoodsAD/drink_bottle] Loading model and processing 12 images...
#   [profile-tail] 12 imgs | read 24.2 ms/img | infer 145.7 ms/img | build 1.4 ms/img | save 0.0 ms/img | gpu alloc/reserved 1.07/1.24 GB
#   Done: 12 images in 2.1s (171ms/img)
#
# [GoodsAD/drink_can] Loading model and processing 12 images...
#   [profile-tail] 12 imgs | read 19.4 ms/img | infer 10.9 ms/img | build 1.5 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.41/12.91 GB
#   Done: 12 images in 0.4s (32ms/img)
#
# [GoodsAD/food_bottle] Loading model and processing 12 images...
#   [profile-tail] 12 imgs | read 20.1 ms/img | infer 97.9 ms/img | build 1.3 ms/img | save 0.0 ms/img | gpu alloc/reserved 1.44/34.96 GB
#   Done: 12 images in 1.4s (119ms/img)
#
# [GoodsAD/food_box] Loading model and processing 12 images...
#   [profile-tail] 12 imgs | read 18.5 ms/img | infer 17.3 ms/img | build 1.4 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.67/23.56 GB
#   Done: 12 images in 0.4s (37ms/img)
#
# [GoodsAD/food_package] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 21.4 ms/img | infer 39.8 ms/img | build 1.4 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.81/0.90 GB
#   Done: 9 images in 0.6s (63ms/img)
#
# [MVTec-LOCO/breakfast_box] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 25.8 ms/img | infer 15.5 ms/img | build 1.5 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.56/19.18 GB
#   Done: 9 images in 0.4s (43ms/img)
#
# [MVTec-LOCO/juice_bottle] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 14.9 ms/img | infer 14.3 ms/img | build 1.5 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.54/18.32 GB
#   Done: 9 images in 0.3s (31ms/img)
#
# [MVTec-LOCO/pushpins] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 19.0 ms/img | infer 16.3 ms/img | build 1.2 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.59/20.32 GB
#   Done: 9 images in 0.3s (37ms/img)
#
# [MVTec-LOCO/screw_bag] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 19.4 ms/img | infer 15.0 ms/img | build 2.0 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.58/19.66 GB
#   Done: 9 images in 0.3s (37ms/img)
#
# ============================================================
# Inference complete
# ============================================================
# Processed (this run): 99
# Skipped (no model): 0
# Errors: 0
# Total inference time: 4.95s
# Average: 50.0ms/img
# Output saved to: output/gemma3-12b/rag/pdf/patchcore_predictions.json
#
# Sample output:
# {
#   "context_version": "ad_context_v2",
#   "image_path": "GoodsAD/cigarette_box/test/good/003_001.jpg",
#   "dataset": "GoodsAD",
#   "category": "cigarette_box",
#   "backend": "ckpt",
#   "anomaly_score": 0.5305,
#   "model_is_anomaly": true,
#   "model_threshold": 0.5,
#   "decision": "normal",
#   "review_needed": false,
#   "decision_confidence": 1.0,
#   "decision_basis": {
#     "center_threshold": 0.5911,
#     "uncertainty_band": 0.02,
#     "score_delta": -0.0606,
#     "used_calibration": true
#   },
#   "class_key": "GoodsAD/cigarette_box",
#   "confidence": {
#     "level": "low",
#     "reliability": "high",
#     "reason": "Score near threshold neighborhood",
#     "reliability_reason": "Policy marks this class as high reliability. Calibrated AUROC=0.910."
#   },
#   "defect_location_raw": {
#     "has_defect": true,
#     "region": "center",
#     "bbox": [
#       1648,
#       461,
#       2242,
#       1930
#     ],
#     "center": [
#       0.648,
#       0.398
#     ],
#     "area_ratio": 0.0132,
#     "confidence": 0.5972
#   },
#   "defect_location": {
#     "has_defect": false,
#     "region": "none",
#     "bbox": null,
#     "center": null,
#     "area_ratio": 0.0,
#     "location_confidence": 0.8587
#   },
#   "use_location_for_report": false,
#   "report_guidance": {
#     "use_ad_for_anomaly_judgement": "high",
#     "use_ad_for_location": "high",
#     "ad_weight": 0.7,
#     "location_confidence": 0.8587,
#     "decision_confidence": 1.0,
#     "instruction": "AD evidence is strong for anomaly existence. Use location hints only if they are consistent with the image.",
#     "reason_codes": [
#       "STRONG_NORMAL_MARGIN"
#     ]
#   },
#   "reason_codes": [
#     "STRONG_NORMAL_MARGIN"
#   ],
#   "map_stats": {
#     "max": 0.5972,
#     "mean": 0.2891,
#     "std": 0.0794
#   }
# }
# Loaded 99 AD predictions
#
# Warming up model (pre-loading weights)...
# Device: NVIDIA A100-SXM4-40GB
# Loading checkpoint shards: 100% 5/5 [00:47<00:00,  9.48s/it]
# Model ready.
#
# Evaluating: 100%|████████████████████████| 99/99 [03:23<00:00,  2.06s/it, acc=77.1%, done=99, err=0]
#
# ============================================================
# Latency by Class
# ============================================================
#   Class                               N   Avg(s)   Total(s)
# ------------------------------------------------------------
#   GoodsAD/cigarette_box               6     4.80      28.78
#   GoodsAD/drink_bottle               12     3.04      36.48
#   GoodsAD/drink_can                  12     1.93      23.21
#   GoodsAD/food_bottle                12     1.67      20.03
#   GoodsAD/food_box                   12     1.73      20.72
#   GoodsAD/food_package                9     1.79      16.15
#   MVTec-LOCO/breakfast_box            9     1.59      14.34
#   MVTec-LOCO/juice_bottle             9     1.54      13.85
#   MVTec-LOCO/pushpins                 9     1.43      12.86
#   MVTec-LOCO/screw_bag                9     1.54      13.86
# ------------------------------------------------------------
#   Overall                            99     2.06      203.6
#
#
# ============================================================
# Calculating Metrics
# ============================================================
# Removed 1 invalid answers
#
# === Accuracy Statistics for answers_1_shot_gemma3-12b_Random_template_with_patchcore_v0_rag_99img.json ===
#
#             Anomaly Detection  Object Classification  Object Analysis  Defect Classification  Defect Localization  Defect Description  Defect Analysis     Recall  Precision    F1    Average
# GoodsAD             54.379085                   80.0        82.222222              76.470588            59.523810           91.428571        93.023256  91.111111  74.545455  82.0  76.721076
# MVTec-LOCO          79.166667                  100.0        77.142857              87.500000            43.478261           65.217391        80.000000  91.666667  84.615385  88.0  76.072168
# Average             66.772876                   90.0        79.682540              81.985294            51.501035           78.322981        86.511628  91.388889  79.580420  85.0  76.396622
#
# === Overall Average ===
# Anomaly Detection        66.772876
# Object Classification    90.000000
# Object Analysis          79.682540
# Defect Classification    81.985294
# Defect Localization      51.501035
# Defect Description       78.322981
# Defect Analysis          86.511628
# Recall                   91.388889
# Precision                79.580420
# F1                       85.000000
# Average                  76.396622
# Name: Average, dtype: float64
#
# Saved accuracy CSV to: output/gemma3-12b/rag/pdf/answers_1_shot_gemma3-12b_Random_template_with_patchcore_v0_rag_99img_accuracy.csv
#
# Results saved to: output/gemma3-12b/rag/pdf/answers_1_shot_gemma3-12b_Random_template_with_patchcore_v0_rag_99img.json
# Metadata saved to: output/gemma3-12b/rag/pdf/answers_1_shot_gemma3-12b_Random_template_with_patchcore_v0_rag_99img.meta.json
# Elapsed: 203.6s

# %%
from src.utils.loaders import load_json

# setting
# gemma3-4b-int4, gemma3-12b-int4, gemma3-27b-int4
# gemma3-4b-int8, gemma3-12b-int8, gemma3-27b-int8

LLM = "gemma3-12b-int4"

# %%
# With RAG
# !uv pip install --upgrade torchao
# !python scripts/run_experiment.py \
    --llm {LLM} \
    --ad-model "patchcore" \
    --rag \
    --data-root {DATA_ROOT} \
    --sample-per-folder {SAMPLE_PER_FOLDER} \
    --output-dir {OUTPUT_ORIGIN} \
    --mmad-json {MMAD_CLASS_JSON} \
    --batch-mode true
# Out:
# Stratified sampling: 3장/폴더, 33폴더
#   Total: 4224 -> Sampled: 99 (normal=30, anomaly=69)
# 2026-02-22 13:39:26.526578: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771767566.549894   28129 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771767566.557590   28129 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771767566.577145   28129 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771767566.577180   28129 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771767566.577182   28129 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771767566.577186   28129 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# RAG enabled: 146 documents indexed
# ============================================================
# MMAD Experiment Runner
# ============================================================
# Experiment:  patchcore_gemma3-12b-int4_1shot_rag
# LLM:         gemma3-12b-int4
# AD model:    patchcore
# RAG:         enabled
# Few-shot:    1
# Template:    Random_template
# Image size:  (384, 384)
# Images:      99 / 4224
# Data root:   /content/drive/Othercomputers/Mac/multiModal_anomaly_report/dataset/MMAD
# Output:      output/gemma3-12b/rag/original/answers_1_shot_gemma3-12b-int4_Random_template_with_patchcore_v0_rag_99img.json
# ============================================================
#
# Filtered MMAD json: 99 images -> output/gemma3-12b/rag/original/_sampled_mmad.json
#
# ============================================================
# Running AD Model Inference
# ============================================================
# Script:       /content/drive/Othercomputers/Mac/multiModal_anomaly_report/scripts/run_ad_inference.py
# Config:       configs/anomaly.yaml
# Checkpoint:   /content/drive/Othercomputers/Mac/multiModal_anomaly_report/dataset/MMAD/checkpoints/patchcore_384
# Version:      v0
# Data root:    /content/drive/Othercomputers/Mac/multiModal_anomaly_report/dataset/MMAD
# MMAD JSON:    output/gemma3-12b/rag/original/_sampled_mmad.json
# Output:       output/gemma3-12b/rag/original/patchcore_predictions.json
#
# Backend: ckpt
# Config: configs/anomaly.yaml
# Output format: report
# Context mode: v2
# Decision rules: configs/ad_policy.json
# Calibration: configs/ad_calibration.json
# Batch size: 8
# IO workers: 8
# Decode reduced: x1
# Save interval: 0
# Profile interval: 128
# Postprocess map: input
# AMP: True
# Keep model cache: False
# Version: v0
# Filters: datasets=['GoodsAD', 'MVTec-LOCO'] categories=['breakfast_box', 'juice_bottle', 'pushpins', 'screw_bag', 'cigarette_box', 'drink_bottle', 'drink_can', 'food_bottle', 'food_box', 'food_package']
# Input size: (384, 384)
# Device: cuda
#
# Loading MMAD data from: output/gemma3-12b/rag/original/_sampled_mmad.json
# Total images to process: 99
# Available models: 10
#   - GoodsAD/cigarette_box
#   - GoodsAD/drink_bottle
#   - GoodsAD/drink_can
#   - GoodsAD/food_bottle
#   - GoodsAD/food_box
#   - GoodsAD/food_package
#   - MVTec-LOCO/breakfast_box
#   - MVTec-LOCO/juice_bottle
#   - MVTec-LOCO/pushpins
#   - MVTec-LOCO/screw_bag
#
# ============================================================
# Running inference
# ============================================================
# Images to process: 99 across 10 categories
#
# [GoodsAD/cigarette_box] Loading model and processing 6 images...
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:213: Attribute 'pre_processor' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['pre_processor'])`.
#   [profile-tail] 6 imgs | read 28.3 ms/img | infer 131.0 ms/img | build 1.3 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.34/0.54 GB
#   Done: 6 images in 1.0s (161ms/img)
#
# [GoodsAD/drink_bottle] Loading model and processing 12 images...
#   [profile-tail] 12 imgs | read 23.3 ms/img | infer 148.0 ms/img | build 1.5 ms/img | save 0.0 ms/img | gpu alloc/reserved 1.07/1.24 GB
#   Done: 12 images in 2.1s (173ms/img)
#
# [GoodsAD/drink_can] Loading model and processing 12 images...
#   [profile-tail] 12 imgs | read 20.3 ms/img | infer 10.8 ms/img | build 1.5 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.41/12.91 GB
#   Done: 12 images in 0.4s (33ms/img)
#
# [GoodsAD/food_bottle] Loading model and processing 12 images...
#   [profile-tail] 12 imgs | read 23.5 ms/img | infer 95.2 ms/img | build 1.4 ms/img | save 0.0 ms/img | gpu alloc/reserved 1.44/34.96 GB
#   Done: 12 images in 1.4s (120ms/img)
#
# [GoodsAD/food_box] Loading model and processing 12 images...
#   [profile-tail] 12 imgs | read 20.2 ms/img | infer 18.0 ms/img | build 1.4 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.67/23.56 GB
#   Done: 12 images in 0.5s (40ms/img)
#
# [GoodsAD/food_package] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 22.1 ms/img | infer 45.0 ms/img | build 1.4 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.81/0.90 GB
#   Done: 9 images in 0.6s (69ms/img)
#
# [MVTec-LOCO/breakfast_box] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 25.0 ms/img | infer 19.0 ms/img | build 1.5 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.56/19.18 GB
#   Done: 9 images in 0.4s (46ms/img)
#
# [MVTec-LOCO/juice_bottle] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 16.4 ms/img | infer 14.2 ms/img | build 1.5 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.54/18.32 GB
#   Done: 9 images in 0.3s (32ms/img)
#
# [MVTec-LOCO/pushpins] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 19.3 ms/img | infer 16.6 ms/img | build 1.2 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.59/20.32 GB
#   Done: 9 images in 0.3s (37ms/img)
#
# [MVTec-LOCO/screw_bag] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 19.5 ms/img | infer 14.8 ms/img | build 2.2 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.58/19.66 GB
#   Done: 9 images in 0.3s (37ms/img)
#
# ============================================================
# Inference complete
# ============================================================
# Processed (this run): 99
# Skipped (no model): 0
# Errors: 0
# Total inference time: 5.04s
# Average: 50.9ms/img
# Output saved to: output/gemma3-12b/rag/original/patchcore_predictions.json
#
# Sample output:
# {
#   "context_version": "ad_context_v2",
#   "image_path": "GoodsAD/cigarette_box/test/good/003_001.jpg",
#   "dataset": "GoodsAD",
#   "category": "cigarette_box",
#   "backend": "ckpt",
#   "anomaly_score": 0.5305,
#   "model_is_anomaly": true,
#   "model_threshold": 0.5,
#   "decision": "normal",
#   "review_needed": false,
#   "decision_confidence": 1.0,
#   "decision_basis": {
#     "center_threshold": 0.5911,
#     "uncertainty_band": 0.02,
#     "score_delta": -0.0606,
#     "used_calibration": true
#   },
#   "class_key": "GoodsAD/cigarette_box",
#   "confidence": {
#     "level": "low",
#     "reliability": "high",
#     "reason": "Score near threshold neighborhood",
#     "reliability_reason": "Policy marks this class as high reliability. Calibrated AUROC=0.910."
#   },
#   "defect_location_raw": {
#     "has_defect": true,
#     "region": "center",
#     "bbox": [
#       1648,
#       461,
#       2242,
#       1930
#     ],
#     "center": [
#       0.648,
#       0.398
#     ],
#     "area_ratio": 0.0132,
#     "confidence": 0.5972
#   },
#   "defect_location": {
#     "has_defect": false,
#     "region": "none",
#     "bbox": null,
#     "center": null,
#     "area_ratio": 0.0,
#     "location_confidence": 0.8587
#   },
#   "use_location_for_report": false,
#   "report_guidance": {
#     "use_ad_for_anomaly_judgement": "high",
#     "use_ad_for_location": "high",
#     "ad_weight": 0.7,
#     "location_confidence": 0.8587,
#     "decision_confidence": 1.0,
#     "instruction": "AD evidence is strong for anomaly existence. Use location hints only if they are consistent with the image.",
#     "reason_codes": [
#       "STRONG_NORMAL_MARGIN"
#     ]
#   },
#   "reason_codes": [
#     "STRONG_NORMAL_MARGIN"
#   ],
#   "map_stats": {
#     "max": 0.5972,
#     "mean": 0.2891,
#     "std": 0.0794
#   }
# }
# Loaded 99 AD predictions
#
# Warming up model (pre-loading weights)...
# Device: NVIDIA A100-SXM4-40GB
# Loading checkpoint shards: 100% 2/2 [00:14<00:00,  7.47s/it]
# Model ready.
#
# Evaluating: 100%|████████████████████████| 99/99 [06:14<00:00,  3.79s/it, acc=76.4%, done=99, err=0]
#
# ============================================================
# Latency by Class
# ============================================================
#   Class                               N   Avg(s)   Total(s)
# ------------------------------------------------------------
#   GoodsAD/cigarette_box               6     6.52      39.10
#   GoodsAD/drink_bottle               12     4.86      58.32
#   GoodsAD/drink_can                  12     3.57      42.79
#   GoodsAD/food_bottle                12     3.31      39.77
#   GoodsAD/food_box                   12     3.43      41.21
#   GoodsAD/food_package                9     3.46      31.14
#   MVTec-LOCO/breakfast_box            9     3.33      29.96
#   MVTec-LOCO/juice_bottle             9     3.40      30.58
#   MVTec-LOCO/pushpins                 9     3.15      28.32
#   MVTec-LOCO/screw_bag                9     3.40      30.56
# ------------------------------------------------------------
#   Overall                            99     3.79      374.8
#
#
# ============================================================
# Calculating Metrics
# ============================================================
#
# === Accuracy Statistics for answers_1_shot_gemma3-12b-int4_Random_template_with_patchcore_v0_rag_99img.json ===
#
#             Anomaly Detection  Object Classification  Object Analysis  Defect Classification  Defect Localization  Defect Description  Defect Analysis     Recall  Precision         F1    Average
# GoodsAD             59.542484              80.000000        82.222222              70.588235            59.523810           80.000000        90.697674  95.555556  76.785714  85.148515  74.653489
# MVTec-LOCO          79.166667              83.333333        85.714286              87.500000            47.826087           65.217391        71.428571  91.666667  84.615385  88.000000  74.312334
# Average             69.354575              81.666667        83.968254              79.044118            53.674948           72.608696        81.063123  93.611111  80.700549  86.574257  74.482911
#
# === Overall Average ===
# Anomaly Detection        69.354575
# Object Classification    81.666667
# Object Analysis          83.968254
# Defect Classification    79.044118
# Defect Localization      53.674948
# Defect Description       72.608696
# Defect Analysis          81.063123
# Recall                   93.611111
# Precision                80.700549
# F1                       86.574257
# Average                  74.482911
# Name: Average, dtype: float64
#
# Saved accuracy CSV to: output/gemma3-12b/rag/original/answers_1_shot_gemma3-12b-int4_Random_template_with_patchcore_v0_rag_99img_accuracy.csv
#
# Results saved to: output/gemma3-12b/rag/original/answers_1_shot_gemma3-12b-int4_Random_template_with_patchcore_v0_rag_99img.json
# Metadata saved to: output/gemma3-12b/rag/original/answers_1_shot_gemma3-12b-int4_Random_template_with_patchcore_v0_rag_99img.meta.json
# Elapsed: 374.8s

# %%
# json + pdf
# !python scripts/run_experiment.py \
    --llm {LLM} --ad-model "patchcore" --rag \
    --rag-persist-dir vectorstore/domain_knowledge_pdf \
    --data-root {DATA_ROOT} --mmad-json {MMAD_CLASS_JSON} \
    --sample-per-folder {SAMPLE_PER_FOLDER} \
    --output-dir {OUTPUT_PDF} --batch-mode true
# Out:
# Stratified sampling: 3장/폴더, 33폴더
#   Total: 4224 -> Sampled: 99 (normal=30, anomaly=69)
# 2026-02-22 13:48:11.571967: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771768091.594859   30715 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771768091.602519   30715 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771768091.622021   30715 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771768091.622055   30715 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771768091.622058   30715 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771768091.622061   30715 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# RAG enabled: 166 documents indexed
# ============================================================
# MMAD Experiment Runner
# ============================================================
# Experiment:  patchcore_gemma3-12b-int4_1shot_rag
# LLM:         gemma3-12b-int4
# AD model:    patchcore
# RAG:         enabled
# Few-shot:    1
# Template:    Random_template
# Image size:  (384, 384)
# Images:      99 / 4224
# Data root:   /content/drive/Othercomputers/Mac/multiModal_anomaly_report/dataset/MMAD
# Output:      output/gemma3-12b/rag/pdf/answers_1_shot_gemma3-12b-int4_Random_template_with_patchcore_v0_rag_99img.json
# ============================================================
#
# Filtered MMAD json: 99 images -> output/gemma3-12b/rag/pdf/_sampled_mmad.json
#
# ============================================================
# Running AD Model Inference
# ============================================================
# Script:       /content/drive/Othercomputers/Mac/multiModal_anomaly_report/scripts/run_ad_inference.py
# Config:       configs/anomaly.yaml
# Checkpoint:   /content/drive/Othercomputers/Mac/multiModal_anomaly_report/dataset/MMAD/checkpoints/patchcore_384
# Version:      v0
# Data root:    /content/drive/Othercomputers/Mac/multiModal_anomaly_report/dataset/MMAD
# MMAD JSON:    output/gemma3-12b/rag/pdf/_sampled_mmad.json
# Output:       output/gemma3-12b/rag/pdf/patchcore_predictions.json
#
# Backend: ckpt
# Config: configs/anomaly.yaml
# Output format: report
# Context mode: v2
# Decision rules: configs/ad_policy.json
# Calibration: configs/ad_calibration.json
# Batch size: 8
# IO workers: 8
# Decode reduced: x1
# Save interval: 0
# Profile interval: 128
# Postprocess map: input
# AMP: True
# Keep model cache: False
# Version: v0
# Filters: datasets=['GoodsAD', 'MVTec-LOCO'] categories=['breakfast_box', 'juice_bottle', 'pushpins', 'screw_bag', 'cigarette_box', 'drink_bottle', 'drink_can', 'food_bottle', 'food_box', 'food_package']
# Input size: (384, 384)
# Device: cuda
#
# Loading MMAD data from: output/gemma3-12b/rag/pdf/_sampled_mmad.json
# Total images to process: 99
# Available models: 10
#   - GoodsAD/cigarette_box
#   - GoodsAD/drink_bottle
#   - GoodsAD/drink_can
#   - GoodsAD/food_bottle
#   - GoodsAD/food_box
#   - GoodsAD/food_package
#   - MVTec-LOCO/breakfast_box
#   - MVTec-LOCO/juice_bottle
#   - MVTec-LOCO/pushpins
#   - MVTec-LOCO/screw_bag
#
# ============================================================
# Running inference
# ============================================================
# Images to process: 99 across 10 categories
#
# [GoodsAD/cigarette_box] Loading model and processing 6 images...
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:213: Attribute 'pre_processor' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['pre_processor'])`.
#   [profile-tail] 6 imgs | read 27.8 ms/img | infer 133.1 ms/img | build 1.3 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.34/0.54 GB
#   Done: 6 images in 1.0s (163ms/img)
#
# [GoodsAD/drink_bottle] Loading model and processing 12 images...
#   [profile-tail] 12 imgs | read 25.4 ms/img | infer 145.6 ms/img | build 1.4 ms/img | save 0.0 ms/img | gpu alloc/reserved 1.07/1.24 GB
#   Done: 12 images in 2.1s (173ms/img)
#
# [GoodsAD/drink_can] Loading model and processing 12 images...
#   [profile-tail] 12 imgs | read 19.5 ms/img | infer 10.7 ms/img | build 1.5 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.41/12.91 GB
#   Done: 12 images in 0.4s (32ms/img)
#
# [GoodsAD/food_bottle] Loading model and processing 12 images...
#   [profile-tail] 12 imgs | read 19.5 ms/img | infer 97.0 ms/img | build 1.3 ms/img | save 0.0 ms/img | gpu alloc/reserved 1.44/34.96 GB
#   Done: 12 images in 1.4s (118ms/img)
#
# [GoodsAD/food_box] Loading model and processing 12 images...
#   [profile-tail] 12 imgs | read 20.6 ms/img | infer 17.3 ms/img | build 1.3 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.67/23.56 GB
#   Done: 12 images in 0.5s (39ms/img)
#
# [GoodsAD/food_package] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 21.5 ms/img | infer 40.4 ms/img | build 1.4 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.81/0.90 GB
#   Done: 9 images in 0.6s (63ms/img)
#
# [MVTec-LOCO/breakfast_box] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 24.2 ms/img | infer 16.0 ms/img | build 1.5 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.56/19.18 GB
#   Done: 9 images in 0.4s (42ms/img)
#
# [MVTec-LOCO/juice_bottle] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 14.5 ms/img | infer 13.9 ms/img | build 1.4 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.54/18.32 GB
#   Done: 9 images in 0.3s (30ms/img)
#
# [MVTec-LOCO/pushpins] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 21.2 ms/img | infer 16.1 ms/img | build 1.2 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.59/20.32 GB
#   Done: 9 images in 0.3s (39ms/img)
#
# [MVTec-LOCO/screw_bag] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 19.4 ms/img | infer 14.5 ms/img | build 2.0 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.58/19.66 GB
#   Done: 9 images in 0.3s (36ms/img)
#
# ============================================================
# Inference complete
# ============================================================
# Processed (this run): 99
# Skipped (no model): 0
# Errors: 0
# Total inference time: 4.95s
# Average: 50.0ms/img
# Output saved to: output/gemma3-12b/rag/pdf/patchcore_predictions.json
#
# Sample output:
# {
#   "context_version": "ad_context_v2",
#   "image_path": "GoodsAD/cigarette_box/test/good/003_001.jpg",
#   "dataset": "GoodsAD",
#   "category": "cigarette_box",
#   "backend": "ckpt",
#   "anomaly_score": 0.5305,
#   "model_is_anomaly": true,
#   "model_threshold": 0.5,
#   "decision": "normal",
#   "review_needed": false,
#   "decision_confidence": 1.0,
#   "decision_basis": {
#     "center_threshold": 0.5911,
#     "uncertainty_band": 0.02,
#     "score_delta": -0.0606,
#     "used_calibration": true
#   },
#   "class_key": "GoodsAD/cigarette_box",
#   "confidence": {
#     "level": "low",
#     "reliability": "high",
#     "reason": "Score near threshold neighborhood",
#     "reliability_reason": "Policy marks this class as high reliability. Calibrated AUROC=0.910."
#   },
#   "defect_location_raw": {
#     "has_defect": true,
#     "region": "center",
#     "bbox": [
#       1648,
#       461,
#       2242,
#       1930
#     ],
#     "center": [
#       0.648,
#       0.398
#     ],
#     "area_ratio": 0.0132,
#     "confidence": 0.5972
#   },
#   "defect_location": {
#     "has_defect": false,
#     "region": "none",
#     "bbox": null,
#     "center": null,
#     "area_ratio": 0.0,
#     "location_confidence": 0.8587
#   },
#   "use_location_for_report": false,
#   "report_guidance": {
#     "use_ad_for_anomaly_judgement": "high",
#     "use_ad_for_location": "high",
#     "ad_weight": 0.7,
#     "location_confidence": 0.8587,
#     "decision_confidence": 1.0,
#     "instruction": "AD evidence is strong for anomaly existence. Use location hints only if they are consistent with the image.",
#     "reason_codes": [
#       "STRONG_NORMAL_MARGIN"
#     ]
#   },
#   "reason_codes": [
#     "STRONG_NORMAL_MARGIN"
#   ],
#   "map_stats": {
#     "max": 0.5972,
#     "mean": 0.2891,
#     "std": 0.0794
#   }
# }
# Loaded 99 AD predictions
#
# Warming up model (pre-loading weights)...
# Device: NVIDIA A100-SXM4-40GB
# Loading checkpoint shards: 100% 2/2 [00:03<00:00,  1.59s/it]
# Model ready.
#
# Evaluating: 100%|████████████████████████| 99/99 [06:12<00:00,  3.76s/it, acc=76.4%, done=99, err=0]
#
# ============================================================
# Latency by Class
# ============================================================
#   Class                               N   Avg(s)   Total(s)
# ------------------------------------------------------------
#   GoodsAD/cigarette_box               6     6.32      37.89
#   GoodsAD/drink_bottle               12     4.83      57.97
#   GoodsAD/drink_can                  12     3.56      42.77
#   GoodsAD/food_bottle                12     3.33      39.96
#   GoodsAD/food_box                   12     3.41      40.96
#   GoodsAD/food_package                9     3.46      31.13
#   MVTec-LOCO/breakfast_box            9     3.35      30.13
#   MVTec-LOCO/juice_bottle             9     3.36      30.28
#   MVTec-LOCO/pushpins                 9     3.13      28.16
#   MVTec-LOCO/screw_bag                9     3.38      30.38
# ------------------------------------------------------------
#   Overall                            99     3.76      372.6
#
#
# ============================================================
# Calculating Metrics
# ============================================================
#
# === Accuracy Statistics for answers_1_shot_gemma3-12b-int4_Random_template_with_patchcore_v0_rag_99img.json ===
#
#             Anomaly Detection  Object Classification  Object Analysis  Defect Classification  Defect Localization  Defect Description  Defect Analysis     Recall  Precision         F1    Average
# GoodsAD             59.542484              80.000000        82.222222              70.588235            59.523810           80.000000        90.697674  95.555556  76.785714  85.148515  74.653489
# MVTec-LOCO          79.166667              83.333333        85.714286              87.500000            47.826087           65.217391        71.428571  91.666667  84.615385  88.000000  74.312334
# Average             69.354575              81.666667        83.968254              79.044118            53.674948           72.608696        81.063123  93.611111  80.700549  86.574257  74.482911
#
# === Overall Average ===
# Anomaly Detection        69.354575
# Object Classification    81.666667
# Object Analysis          83.968254
# Defect Classification    79.044118
# Defect Localization      53.674948
# Defect Description       72.608696
# Defect Analysis          81.063123
# Recall                   93.611111
# Precision                80.700549
# F1                       86.574257
# Average                  74.482911
# Name: Average, dtype: float64
#
# Saved accuracy CSV to: output/gemma3-12b/rag/pdf/answers_1_shot_gemma3-12b-int4_Random_template_with_patchcore_v0_rag_99img_accuracy.csv
#
# Results saved to: output/gemma3-12b/rag/pdf/answers_1_shot_gemma3-12b-int4_Random_template_with_patchcore_v0_rag_99img.json
# Metadata saved to: output/gemma3-12b/rag/pdf/answers_1_shot_gemma3-12b-int4_Random_template_with_patchcore_v0_rag_99img.meta.json
# Elapsed: 372.6s

# %%
# With RAG
LLM = "gemma3-27b-int4"
# !python scripts/run_experiment.py \
    --llm {LLM} \
    --ad-model "patchcore" \
    --rag \
    --data-root {DATA_ROOT} \
    --sample-per-folder {SAMPLE_PER_FOLDER} \
    --output-dir {OUTPUT_ORIGIN} \
    --mmad-json {MMAD_CLASS_JSON} \
    --batch-mode true
# Out:
# Stratified sampling: 3장/폴더, 33폴더
#   Total: 4224 -> Sampled: 99 (normal=30, anomaly=69)
# 2026-02-22 13:07:53.776582: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771765673.801264   18935 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771765673.809239   18935 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771765673.830281   18935 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771765673.830324   18935 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771765673.830327   18935 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771765673.830330   18935 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# RAG enabled: 146 documents indexed
# ============================================================
# MMAD Experiment Runner
# ============================================================
# Experiment:  patchcore_gemma3-27b-int4_1shot_rag
# LLM:         gemma3-27b-int4
# AD model:    patchcore
# RAG:         enabled
# Few-shot:    1
# Template:    Random_template
# Image size:  (384, 384)
# Images:      99 / 4224
# Data root:   /content/drive/Othercomputers/Mac/multiModal_anomaly_report/dataset/MMAD
# Output:      output/gemma3-12b/rag/original/answers_1_shot_gemma3-27b-int4_Random_template_with_patchcore_v0_rag_99img.json
# ============================================================
#
# Filtered MMAD json: 99 images -> output/gemma3-12b/rag/original/_sampled_mmad.json
#
# ============================================================
# Running AD Model Inference
# ============================================================
# Script:       /content/drive/Othercomputers/Mac/multiModal_anomaly_report/scripts/run_ad_inference.py
# Config:       configs/anomaly.yaml
# Checkpoint:   /content/drive/Othercomputers/Mac/multiModal_anomaly_report/dataset/MMAD/checkpoints/patchcore_384
# Version:      v0
# Data root:    /content/drive/Othercomputers/Mac/multiModal_anomaly_report/dataset/MMAD
# MMAD JSON:    output/gemma3-12b/rag/original/_sampled_mmad.json
# Output:       output/gemma3-12b/rag/original/patchcore_predictions.json
#
# Backend: ckpt
# Config: configs/anomaly.yaml
# Output format: report
# Context mode: v2
# Decision rules: configs/ad_policy.json
# Calibration: configs/ad_calibration.json
# Batch size: 8
# IO workers: 8
# Decode reduced: x1
# Save interval: 0
# Profile interval: 128
# Postprocess map: input
# AMP: True
# Keep model cache: False
# Version: v0
# Filters: datasets=['GoodsAD', 'MVTec-LOCO'] categories=['breakfast_box', 'juice_bottle', 'pushpins', 'screw_bag', 'cigarette_box', 'drink_bottle', 'drink_can', 'food_bottle', 'food_box', 'food_package']
# Input size: (384, 384)
# Device: cuda
#
# Loading MMAD data from: output/gemma3-12b/rag/original/_sampled_mmad.json
# Total images to process: 99
# Available models: 10
#   - GoodsAD/cigarette_box
#   - GoodsAD/drink_bottle
#   - GoodsAD/drink_can
#   - GoodsAD/food_bottle
#   - GoodsAD/food_box
#   - GoodsAD/food_package
#   - MVTec-LOCO/breakfast_box
#   - MVTec-LOCO/juice_bottle
#   - MVTec-LOCO/pushpins
#   - MVTec-LOCO/screw_bag
#
# ============================================================
# Running inference
# ============================================================
# Images to process: 99 across 10 categories
#
# [GoodsAD/cigarette_box] Loading model and processing 6 images...
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:213: Attribute 'pre_processor' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['pre_processor'])`.
#   [profile-tail] 6 imgs | read 25.9 ms/img | infer 131.8 ms/img | build 1.4 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.34/0.54 GB
#   Done: 6 images in 1.0s (159ms/img)
#
# [GoodsAD/drink_bottle] Loading model and processing 12 images...
#   [profile-tail] 12 imgs | read 20.2 ms/img | infer 144.4 ms/img | build 1.4 ms/img | save 0.0 ms/img | gpu alloc/reserved 1.07/1.24 GB
#   Done: 12 images in 2.0s (166ms/img)
#
# [GoodsAD/drink_can] Loading model and processing 12 images...
#   [profile-tail] 12 imgs | read 22.7 ms/img | infer 10.8 ms/img | build 1.5 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.41/12.91 GB
#   Done: 12 images in 0.4s (35ms/img)
#
# [GoodsAD/food_bottle] Loading model and processing 12 images...
#   [profile-tail] 12 imgs | read 18.5 ms/img | infer 96.9 ms/img | build 1.4 ms/img | save 0.0 ms/img | gpu alloc/reserved 1.44/34.96 GB
#   Done: 12 images in 1.4s (117ms/img)
#
# [GoodsAD/food_box] Loading model and processing 12 images...
#   [profile-tail] 12 imgs | read 19.4 ms/img | infer 16.7 ms/img | build 1.4 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.67/23.56 GB
#   Done: 12 images in 0.5s (38ms/img)
#
# [GoodsAD/food_package] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 24.5 ms/img | infer 40.7 ms/img | build 1.4 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.81/0.90 GB
#   Done: 9 images in 0.6s (67ms/img)
#
# [MVTec-LOCO/breakfast_box] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 23.8 ms/img | infer 16.3 ms/img | build 1.5 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.56/19.18 GB
#   Done: 9 images in 0.4s (42ms/img)
#
# [MVTec-LOCO/juice_bottle] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 15.4 ms/img | infer 13.9 ms/img | build 1.5 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.54/18.32 GB
#   Done: 9 images in 0.3s (31ms/img)
#
# [MVTec-LOCO/pushpins] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 18.9 ms/img | infer 15.7 ms/img | build 1.2 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.59/20.32 GB
#   Done: 9 images in 0.3s (36ms/img)
#
# [MVTec-LOCO/screw_bag] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 21.0 ms/img | infer 14.8 ms/img | build 1.9 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.58/19.66 GB
#   Done: 9 images in 0.3s (38ms/img)
#
# ============================================================
# Inference complete
# ============================================================
# Processed (this run): 99
# Skipped (no model): 0
# Errors: 0
# Total inference time: 4.93s
# Average: 49.8ms/img
# Output saved to: output/gemma3-12b/rag/original/patchcore_predictions.json
#
# Sample output:
# {
#   "context_version": "ad_context_v2",
#   "image_path": "GoodsAD/cigarette_box/test/good/003_001.jpg",
#   "dataset": "GoodsAD",
#   "category": "cigarette_box",
#   "backend": "ckpt",
#   "anomaly_score": 0.5305,
#   "model_is_anomaly": true,
#   "model_threshold": 0.5,
#   "decision": "normal",
#   "review_needed": false,
#   "decision_confidence": 1.0,
#   "decision_basis": {
#     "center_threshold": 0.5911,
#     "uncertainty_band": 0.02,
#     "score_delta": -0.0606,
#     "used_calibration": true
#   },
#   "class_key": "GoodsAD/cigarette_box",
#   "confidence": {
#     "level": "low",
#     "reliability": "high",
#     "reason": "Score near threshold neighborhood",
#     "reliability_reason": "Policy marks this class as high reliability. Calibrated AUROC=0.910."
#   },
#   "defect_location_raw": {
#     "has_defect": true,
#     "region": "center",
#     "bbox": [
#       1648,
#       461,
#       2242,
#       1930
#     ],
#     "center": [
#       0.648,
#       0.398
#     ],
#     "area_ratio": 0.0133,
#     "confidence": 0.5972
#   },
#   "defect_location": {
#     "has_defect": false,
#     "region": "none",
#     "bbox": null,
#     "center": null,
#     "area_ratio": 0.0,
#     "location_confidence": 0.8587
#   },
#   "use_location_for_report": false,
#   "report_guidance": {
#     "use_ad_for_anomaly_judgement": "high",
#     "use_ad_for_location": "high",
#     "ad_weight": 0.7,
#     "location_confidence": 0.8587,
#     "decision_confidence": 1.0,
#     "instruction": "AD evidence is strong for anomaly existence. Use location hints only if they are consistent with the image.",
#     "reason_codes": [
#       "STRONG_NORMAL_MARGIN"
#     ]
#   },
#   "reason_codes": [
#     "STRONG_NORMAL_MARGIN"
#   ],
#   "map_stats": {
#     "max": 0.5972,
#     "mean": 0.2891,
#     "std": 0.0794
#   }
# }
# Loaded 99 AD predictions
#
# Warming up model (pre-loading weights)...
# Device: NVIDIA A100-SXM4-40GB
# Loading checkpoint shards: 100% 4/4 [00:06<00:00,  1.67s/it]
# Model ready.
#
# Evaluating: 100%|████████████████████████| 99/99 [11:09<00:00,  6.77s/it, acc=81.6%, done=99, err=0]
#
# ============================================================
# Latency by Class
# ============================================================
#   Class                               N   Avg(s)   Total(s)
# ------------------------------------------------------------
#   GoodsAD/cigarette_box               6     9.84      59.03
#   GoodsAD/drink_bottle               12     8.00      96.06
#   GoodsAD/drink_can                  12     6.39      76.62
#   GoodsAD/food_bottle                12     6.09      73.05
#   GoodsAD/food_box                   12     6.35      76.20
#   GoodsAD/food_package                9     6.37      57.32
#   MVTec-LOCO/breakfast_box            9     6.32      56.85
#   MVTec-LOCO/juice_bottle             9     6.56      59.06
#   MVTec-LOCO/pushpins                 9     6.01      54.09
#   MVTec-LOCO/screw_bag                9     6.51      58.62
# ------------------------------------------------------------
#   Overall                            99     6.77      669.9
#
#
# ============================================================
# Calculating Metrics
# ============================================================
#
# === Accuracy Statistics for answers_1_shot_gemma3-27b-int4_Random_template_with_patchcore_v0_rag_99img.json ===
#
#             Anomaly Detection  Object Classification  Object Analysis  Defect Classification  Defect Localization  Defect Description  Defect Analysis     Recall  Precision         F1    Average
# GoodsAD             65.424837                   80.0        80.000000              85.294118            64.285714           94.285714        95.348837  95.555556  79.629630  86.868687  80.662746
# MVTec-LOCO          81.250000                  100.0        77.142857              79.166667            65.217391           78.260870        85.714286  95.833333  85.185185  90.196078  80.964581
# Average             73.337418                   90.0        78.571429              82.230392            64.751553           86.273292        90.531561  95.694444  82.407407  88.532383  80.813664
#
# === Overall Average ===
# Anomaly Detection        73.337418
# Object Classification    90.000000
# Object Analysis          78.571429
# Defect Classification    82.230392
# Defect Localization      64.751553
# Defect Description       86.273292
# Defect Analysis          90.531561
# Recall                   95.694444
# Precision                82.407407
# F1                       88.532383
# Average                  80.813664
# Name: Average, dtype: float64
#
# Saved accuracy CSV to: output/gemma3-12b/rag/original/answers_1_shot_gemma3-27b-int4_Random_template_with_patchcore_v0_rag_99img_accuracy.csv
#
# Results saved to: output/gemma3-12b/rag/original/answers_1_shot_gemma3-27b-int4_Random_template_with_patchcore_v0_rag_99img.json
# Metadata saved to: output/gemma3-12b/rag/original/answers_1_shot_gemma3-27b-int4_Random_template_with_patchcore_v0_rag_99img.meta.json
# Elapsed: 669.9s

# %%
# json + pdf
# !python scripts/run_experiment.py \
    --llm {LLM} --ad-model "patchcore" --rag \
    --rag-persist-dir vectorstore/domain_knowledge_pdf \
    --data-root {DATA_ROOT} --mmad-json {MMAD_CLASS_JSON} \
    --sample-per-folder {SAMPLE_PER_FOLDER} \
    --output-dir {OUTPUT_PDF} --batch-mode true
# Out:
# Stratified sampling: 3장/폴더, 33폴더
#   Total: 4224 -> Sampled: 99 (normal=30, anomaly=69)
# 2026-02-22 12:53:52.673746: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771764832.696405   14870 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771764832.703855   14870 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771764832.722870   14870 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771764832.722903   14870 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771764832.722906   14870 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771764832.722908   14870 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# RAG enabled: 166 documents indexed
# ============================================================
# MMAD Experiment Runner
# ============================================================
# Experiment:  patchcore_gemma3-27b-int4_1shot_rag
# LLM:         gemma3-27b-int4
# AD model:    patchcore
# RAG:         enabled
# Few-shot:    1
# Template:    Random_template
# Image size:  (384, 384)
# Images:      99 / 4224
# Data root:   /content/drive/Othercomputers/Mac/multiModal_anomaly_report/dataset/MMAD
# Output:      output/gemma3-12b/rag/pdf/answers_1_shot_gemma3-27b-int4_Random_template_with_patchcore_v0_rag_99img.json
# ============================================================
#
# Filtered MMAD json: 99 images -> output/gemma3-12b/rag/pdf/_sampled_mmad.json
#
# ============================================================
# Running AD Model Inference
# ============================================================
# Script:       /content/drive/Othercomputers/Mac/multiModal_anomaly_report/scripts/run_ad_inference.py
# Config:       configs/anomaly.yaml
# Checkpoint:   /content/drive/Othercomputers/Mac/multiModal_anomaly_report/dataset/MMAD/checkpoints/patchcore_384
# Version:      v0
# Data root:    /content/drive/Othercomputers/Mac/multiModal_anomaly_report/dataset/MMAD
# MMAD JSON:    output/gemma3-12b/rag/pdf/_sampled_mmad.json
# Output:       output/gemma3-12b/rag/pdf/patchcore_predictions.json
#
# Backend: ckpt
# Config: configs/anomaly.yaml
# Output format: report
# Context mode: v2
# Decision rules: configs/ad_policy.json
# Calibration: configs/ad_calibration.json
# Batch size: 8
# IO workers: 8
# Decode reduced: x1
# Save interval: 0
# Profile interval: 128
# Postprocess map: input
# AMP: True
# Keep model cache: False
# Version: v0
# Filters: datasets=['GoodsAD', 'MVTec-LOCO'] categories=['breakfast_box', 'juice_bottle', 'pushpins', 'screw_bag', 'cigarette_box', 'drink_bottle', 'drink_can', 'food_bottle', 'food_box', 'food_package']
# Input size: (384, 384)
# Device: cuda
#
# Loading MMAD data from: output/gemma3-12b/rag/pdf/_sampled_mmad.json
# Total images to process: 99
# Available models: 10
#   - GoodsAD/cigarette_box
#   - GoodsAD/drink_bottle
#   - GoodsAD/drink_can
#   - GoodsAD/food_bottle
#   - GoodsAD/food_box
#   - GoodsAD/food_package
#   - MVTec-LOCO/breakfast_box
#   - MVTec-LOCO/juice_bottle
#   - MVTec-LOCO/pushpins
#   - MVTec-LOCO/screw_bag
#
# ============================================================
# Running inference
# ============================================================
# Images to process: 99 across 10 categories
#
# [GoodsAD/cigarette_box] Loading model and processing 6 images...
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:213: Attribute 'pre_processor' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['pre_processor'])`.
#   [profile-tail] 6 imgs | read 21.9 ms/img | infer 129.7 ms/img | build 1.3 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.34/0.54 GB
#   Done: 6 images in 0.9s (153ms/img)
#
# [GoodsAD/drink_bottle] Loading model and processing 12 images...
#   [profile-tail] 12 imgs | read 22.1 ms/img | infer 143.9 ms/img | build 1.4 ms/img | save 0.0 ms/img | gpu alloc/reserved 1.07/1.24 GB
#   Done: 12 images in 2.0s (168ms/img)
#
# [GoodsAD/drink_can] Loading model and processing 12 images...
#   [profile-tail] 12 imgs | read 21.4 ms/img | infer 10.8 ms/img | build 1.5 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.41/12.91 GB
#   Done: 12 images in 0.4s (34ms/img)
#
# [GoodsAD/food_bottle] Loading model and processing 12 images...
#   [profile-tail] 12 imgs | read 17.6 ms/img | infer 96.3 ms/img | build 1.3 ms/img | save 0.0 ms/img | gpu alloc/reserved 1.44/34.96 GB
#   Done: 12 images in 1.4s (115ms/img)
#
# [GoodsAD/food_box] Loading model and processing 12 images...
#   [profile-tail] 12 imgs | read 20.8 ms/img | infer 16.3 ms/img | build 1.3 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.67/23.56 GB
#   Done: 12 images in 0.5s (39ms/img)
#
# [GoodsAD/food_package] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 23.9 ms/img | infer 40.2 ms/img | build 1.4 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.81/0.90 GB
#   Done: 9 images in 0.6s (66ms/img)
#
# [MVTec-LOCO/breakfast_box] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 24.6 ms/img | infer 15.4 ms/img | build 1.4 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.56/19.18 GB
#   Done: 9 images in 0.4s (42ms/img)
#
# [MVTec-LOCO/juice_bottle] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 16.2 ms/img | infer 14.1 ms/img | build 1.4 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.54/18.32 GB
#   Done: 9 images in 0.3s (32ms/img)
#
# [MVTec-LOCO/pushpins] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 19.8 ms/img | infer 16.6 ms/img | build 1.2 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.59/20.32 GB
#   Done: 9 images in 0.3s (38ms/img)
#
# [MVTec-LOCO/screw_bag] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 19.6 ms/img | infer 14.7 ms/img | build 1.9 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.58/19.66 GB
#   Done: 9 images in 0.3s (36ms/img)
#
# ============================================================
# Inference complete
# ============================================================
# Processed (this run): 99
# Skipped (no model): 0
# Errors: 0
# Total inference time: 4.90s
# Average: 49.4ms/img
# Output saved to: output/gemma3-12b/rag/pdf/patchcore_predictions.json
#
# Sample output:
# {
#   "context_version": "ad_context_v2",
#   "image_path": "GoodsAD/cigarette_box/test/good/003_001.jpg",
#   "dataset": "GoodsAD",
#   "category": "cigarette_box",
#   "backend": "ckpt",
#   "anomaly_score": 0.5305,
#   "model_is_anomaly": true,
#   "model_threshold": 0.5,
#   "decision": "normal",
#   "review_needed": false,
#   "decision_confidence": 1.0,
#   "decision_basis": {
#     "center_threshold": 0.5911,
#     "uncertainty_band": 0.02,
#     "score_delta": -0.0606,
#     "used_calibration": true
#   },
#   "class_key": "GoodsAD/cigarette_box",
#   "confidence": {
#     "level": "low",
#     "reliability": "high",
#     "reason": "Score near threshold neighborhood",
#     "reliability_reason": "Policy marks this class as high reliability. Calibrated AUROC=0.910."
#   },
#   "defect_location_raw": {
#     "has_defect": true,
#     "region": "center",
#     "bbox": [
#       1648,
#       461,
#       2242,
#       1930
#     ],
#     "center": [
#       0.648,
#       0.398
#     ],
#     "area_ratio": 0.0133,
#     "confidence": 0.5972
#   },
#   "defect_location": {
#     "has_defect": false,
#     "region": "none",
#     "bbox": null,
#     "center": null,
#     "area_ratio": 0.0,
#     "location_confidence": 0.8587
#   },
#   "use_location_for_report": false,
#   "report_guidance": {
#     "use_ad_for_anomaly_judgement": "high",
#     "use_ad_for_location": "high",
#     "ad_weight": 0.7,
#     "location_confidence": 0.8587,
#     "decision_confidence": 1.0,
#     "instruction": "AD evidence is strong for anomaly existence. Use location hints only if they are consistent with the image.",
#     "reason_codes": [
#       "STRONG_NORMAL_MARGIN"
#     ]
#   },
#   "reason_codes": [
#     "STRONG_NORMAL_MARGIN"
#   ],
#   "map_stats": {
#     "max": 0.5972,
#     "mean": 0.2891,
#     "std": 0.0794
#   }
# }
# Loaded 99 AD predictions
#
# Warming up model (pre-loading weights)...
# Device: NVIDIA A100-SXM4-40GB
# Loading checkpoint shards: 100% 4/4 [00:06<00:00,  1.75s/it]
# Model ready.
#
# Evaluating: 100%|████████████████████████| 99/99 [11:08<00:00,  6.75s/it, acc=81.6%, done=99, err=0]
#
# ============================================================
# Latency by Class
# ============================================================
#   Class                               N   Avg(s)   Total(s)
# ------------------------------------------------------------
#   GoodsAD/cigarette_box               6     9.67      58.04
#   GoodsAD/drink_bottle               12     8.02      96.29
#   GoodsAD/drink_can                  12     6.33      76.00
#   GoodsAD/food_bottle                12     6.11      73.27
#   GoodsAD/food_box                   12     6.31      75.68
#   GoodsAD/food_package                9     6.32      56.92
#   MVTec-LOCO/breakfast_box            9     6.37      57.34
#   MVTec-LOCO/juice_bottle             9     6.55      58.94
#   MVTec-LOCO/pushpins                 9     6.01      54.06
#   MVTec-LOCO/screw_bag                9     6.51      58.58
# ------------------------------------------------------------
#   Overall                            99     6.75      668.1
#
#
# ============================================================
# Calculating Metrics
# ============================================================
#
# === Accuracy Statistics for answers_1_shot_gemma3-27b-int4_Random_template_with_patchcore_v0_rag_99img.json ===
#
#             Anomaly Detection  Object Classification  Object Analysis  Defect Classification  Defect Localization  Defect Description  Defect Analysis     Recall  Precision         F1    Average
# GoodsAD              62.48366                   80.0             80.0              85.294118            64.285714           94.285714        95.348837  95.555556  78.181818  86.000000  80.242578
# MVTec-LOCO           81.25000                  100.0             80.0              79.166667            65.217391           78.260870        85.714286  95.833333  85.185185  90.196078  81.372745
# Average              71.86683                   90.0             80.0              82.230392            64.751553           86.273292        90.531561  95.694444  81.683502  88.098039  80.807661
#
# === Overall Average ===
# Anomaly Detection        71.866830
# Object Classification    90.000000
# Object Analysis          80.000000
# Defect Classification    82.230392
# Defect Localization      64.751553
# Defect Description       86.273292
# Defect Analysis          90.531561
# Recall                   95.694444
# Precision                81.683502
# F1                       88.098039
# Average                  80.807661
# Name: Average, dtype: float64
#
# Saved accuracy CSV to: output/gemma3-12b/rag/pdf/answers_1_shot_gemma3-27b-int4_Random_template_with_patchcore_v0_rag_99img_accuracy.csv
#
# Results saved to: output/gemma3-12b/rag/pdf/answers_1_shot_gemma3-27b-int4_Random_template_with_patchcore_v0_rag_99img.json
# Metadata saved to: output/gemma3-12b/rag/pdf/answers_1_shot_gemma3-27b-int4_Random_template_with_patchcore_v0_rag_99img.meta.json
# Elapsed: 668.1s

# %%
# 결과 비교
configs = {
    # "Baseline": OUTPUT_DIR,
    # "AD only": OUTPUT_AD,
    "AD+RAG": OUTPUT_ORIGIN,
    "AD+RAG (+PDF)": OUTPUT_PDF,
}

def load_latest_meta(output_dir):
    files = sorted(Path(output_dir).glob("*.meta.json"))
    if not files:
        return None
    return json.load(open(files[-1]))

rows = {}
for label, out_dir in configs.items():
    meta = load_latest_meta(out_dir)
    rows[label] = meta

# 기준: Baseline accuracy
# bl_acc = rows["Baseline"]["accuracy"] if rows["Baseline"] else 0

print(f"{'Config':<12} {'Accuracy':>10} {'Correct':>9} {'Total':>7} {'Diff':>8}")
print("=" * 52)
for label, meta in rows.items():
    if meta is None:
        print(f"{label:<12} {'결과없음':>10}")
        continue
    acc  = meta.get("accuracy", 0)
    cor  = meta.get("total_correct", 0)
    tot  = meta.get("total_questions", 0)
    # diff = acc - bl_acc
    # sign = "+" if diff > 0 else ""
    # diff_str = f"{sign}{diff:.2f}" if label != "Baseline" else "-"
    print(f"{label:<12} {acc:>9.2f}% {cor:>9} {tot:>7}") # {diff_str:>8}

def load_latest_answers(output_dir):
    files = [f for f in sorted(Path(output_dir).glob("answers_*.json")) if ".meta." not in f.name]
    return json.load(open(files[-1])) if files else []

answers = {label: load_latest_answers(d) for label, d in configs.items()}

# good vs anomaly 정확도
print(f"{'Config':<25} {'good':>8} {'anomaly':>10}")
print("-" * 46)
for label, ans in answers.items():
    good    = [a for a in ans if "/good/" in a["image"]]
    anomaly = [a for a in ans if "/good/" not in a["image"]]
    g_acc = sum(a["gpt_answer"]==a["correct_answer"] for a in good) / len(good) * 100 if good else 0
    a_acc = sum(a["gpt_answer"]==a["correct_answer"] for a in anomaly) / len(anomaly) * 100 if anomaly else 0
    print(f"{label:<25} {g_acc:>7.1f}% {a_acc:>9.1f}%")
# Out:
# Config         Accuracy   Correct   Total     Diff
# ====================================================
# AD+RAG           81.56%       367     450
# AD+RAG (+PDF)     81.56%       367     450
# Config                        good    anomaly
# ----------------------------------------------
# AD+RAG                       74.3%      84.7%
# AD+RAG (+PDF)                74.3%      84.7%
