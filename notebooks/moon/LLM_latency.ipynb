# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import warnings
from pathlib import Path
from collections import Counter, defaultdict
from PIL import Image

warnings.filterwarnings('ignore')

# %%
try:
    import google.colab
    from google.colab import drive

    # !uv pip install anomalib
    # !uv pip install open-clip-torch
    # !uv pip install qwen-vl-utils
    # !uv pip install transformers==4.52.4
    # !uv pip install langchain-chroma langchain-huggingface
    # !uv pip install langchain_community pypdf beautifulsoup4
    # !uv pip install -U bitsandbytes
    # !uv pip install -U torchao
    # !uv pip install rank_bm25

    drive.mount('/content/drive', force_remount=True)

    # Colab Root
    PROJECT_ROOT = Path('/content/drive/Othercomputers/Mac/multiModal_anomaly_report') # 본인 경로 수정: Mac/Window
    DATA_ROOT = PROJECT_ROOT / "dataset" / "MMAD"

except ImportError:

    # Local Root
    PROJECT_ROOT = Path.cwd().parents[1]
    DATA_ROOT = PROJECT_ROOT / "datasets" / "MMAD"

os.chdir(PROJECT_ROOT) # 현재 경로 수정
print(f"Current working directory: {os.getcwd()}")
# Out:
# Using Python 3.12.12 environment at: /usr
# Resolved 98 packages in 1.35s
# Prepared 12 packages in 488ms
# Installed 12 packages in 17ms
#  + anomalib==2.2.0
#  + freia==0.2
#  + imagecodecs==2026.1.14
#  + jsonargparse==4.46.0
#  + kornia==0.8.2
#  + kornia-rs==0.1.10
#  + lightning==2.6.1
#  + lightning-utilities==0.15.3
#  + pytorch-lightning==2.6.1
#  + rich-argparse==1.7.2
#  + torchmetrics==1.8.2
#  + typeshed-client==2.8.2
# Using Python 3.12.12 environment at: /usr
# Resolved 57 packages in 203ms
# Prepared 2 packages in 97ms
# Installed 2 packages in 4ms
#  + ftfy==6.3.1
#  + open-clip-torch==3.2.0
# Using Python 3.12.12 environment at: /usr
# Resolved 9 packages in 157ms
# Prepared 2 packages in 529ms
# Installed 2 packages in 7ms
#  + av==16.1.0
#  + qwen-vl-utils==0.0.14
# Using Python 3.12.12 environment at: /usr
# Resolved 18 packages in 152ms
# Prepared 3 packages in 440ms
# Uninstalled 3 packages in 360ms
# Installed 3 packages in 42ms
#  - huggingface-hub==1.4.1
#  + huggingface-hub==0.36.2
#  - tokenizers==0.22.2
#  + tokenizers==0.21.4
#  - transformers==5.0.0
#  + transformers==4.52.4
# Using Python 3.12.12 environment at: /usr
# Resolved 88 packages in 571ms
# Prepared 14 packages in 540ms
# Installed 14 packages in 20ms
#  + backoff==2.2.1
#  + bcrypt==5.0.0
#  + build==1.4.0
#  + chromadb==1.5.1
#  + durationpy==0.10
#  + kubernetes==35.0.0
#  + langchain-chroma==1.1.0
#  + langchain-huggingface==1.2.0
#  + onnxruntime==1.24.2
#  + opentelemetry-exporter-otlp-proto-grpc==1.38.0
#  + posthog==5.4.0
#  + pybase64==1.4.3
#  + pypika==0.51.1
#  + pyproject-hooks==1.2.0
# Using Python 3.12.12 environment at: /usr
# Resolved 50 packages in 229ms
# Prepared 9 packages in 217ms
# Uninstalled 1 package in 1ms
# Installed 9 packages in 29ms
#  + dataclasses-json==0.6.7
#  + langchain-classic==1.0.1
#  + langchain-community==0.4.1
#  + langchain-text-splitters==1.1.1
#  + marshmallow==3.26.2
#  + mypy-extensions==1.1.0
#  + pypdf==6.7.2
#  - requests==2.32.4
#  + requests==2.32.5
#  + typing-inspect==0.9.0
# Using Python 3.12.12 environment at: /usr
# Resolved 31 packages in 148ms
# Prepared 6 packages in 872ms
# Uninstalled 5 packages in 68ms
# Installed 6 packages in 22ms
#  + bitsandbytes==0.49.2
#  - cuda-pathfinder==1.3.4
#  + cuda-pathfinder==1.3.5
#  - filelock==3.24.2
#  + filelock==3.24.3
#  - fsspec==2025.3.0
#  + fsspec==2026.2.0
#  - numpy==2.0.2
#  + numpy==2.4.2
#  - setuptools==75.2.0
#  + setuptools==82.0.0
# Using Python 3.12.12 environment at: /usr
# Resolved 1 package in 82ms
# Prepared 1 package in 132ms
# Uninstalled 1 package in 29ms
# Installed 1 package in 23ms
#  - torchao==0.10.0
#  + torchao==0.16.0
# Using Python 3.12.12 environment at: /usr
# Resolved 2 packages in 85ms
# Prepared 1 package in 14ms
# Installed 1 package in 2ms
#  + rank-bm25==0.2.2
# Mounted at /content/drive
# Current working directory: /content/drive/Othercomputers/Mac/multiModal_anomaly_report

# %%
# RAG Dataet path
DOMAIN_KNOWLEDGE_ROOT = DATA_ROOT / "domain_knowledge.json"
PDF_PATH = DATA_ROOT / "packaging_guide.pdf"
CFIA_JSON_PATH = DATA_ROOT / "cfia_knowledge.json"

# %%
from src.rag import Indexer, Retrievers, PDFKnowledgeLoader, JSONKnowledgeLoader

pdf_loader = PDFKnowledgeLoader(pdf_path=PDF_PATH, chunk_size=1000, chunk_overlap=100)
pdf_docs = pdf_loader.load()
print(f"PDF Total: {len(pdf_docs)} chunks")

cfia_docs = JSONKnowledgeLoader(CFIA_JSON_PATH).load()
print(f"CFIA Total: {len(cfia_docs)} docs")
# Out:
# PDF Total: 20 chunks
# CFIA Total: 26 docs

# %%
from src.rag import RAGEvaluator, TEST_QUERIES_MMAD

indexers = Indexer(
    json_path=DOMAIN_KNOWLEDGE_ROOT,
    persist_dir="vectorstore/domain_knowledge"
)
vs_config = indexers.get_or_create()
domain_docs = indexers.load_documents()

result_dense = RAGEvaluator(Retrievers(vs_config, documents=domain_docs, mode="dense")).evaluate(TEST_QUERIES_MMAD, k=3)
result_hybrid = RAGEvaluator(Retrievers(vs_config, documents=domain_docs, mode="hybrid")).evaluate(TEST_QUERIES_MMAD, k=3)

print(f"{'Mode':<12} {'Hit Rate':>10} {'MRR':>10}")
print(f"{'Dense':12} {result_dense['hit_rate']:>10.3f} {result_dense['mrr']:>10.3f}")
print(f"{'Hybrid':12} {result_hybrid['hit_rate']:>10.3f} {result_hybrid['mrr']:>10.3f}")
print(f"{'Delta':12} {result_hybrid['hit_rate'] - result_dense['hit_rate']:>+10.3f} {result_hybrid['mrr'] - result_dense['mrr']:>+10.3f}")
# Out:
# Mode           Hit Rate        MRR
# Dense             0.600      0.600
# Hybrid            0.600      0.550
# Delta            +0.000     -0.050

# %%
from src.utils.loaders import load_json

# setting
# gemma3-4b-int4, gemma3-12b-int4, gemma3-27b-int4
# gemma3-4b-int8, gemma3-12b-int8, gemma3-27b-int8

LLM = "gemma3-27b-int4"
MMAD_CLASS_JSON = DATA_ROOT / "mmad_10classes.json"
OUTPUT_DIR = f"output/{LLM}"
OUTPUT_RAG_ROOT = Path(OUTPUT_DIR) / "rag"

OUTPUT_AD = OUTPUT_RAG_ROOT / "AD"
OUTPUT_ORIGIN = OUTPUT_RAG_ROOT / "original"
OUTPUT_PDF = OUTPUT_RAG_ROOT / "pdf"
OUTPUT_CFIA = OUTPUT_RAG_ROOT / "cfia"
OUTPUT_PDF_CFIA = OUTPUT_RAG_ROOT / "pdf_cfia"
SAMPLE_PER_FOLDER = 3  # 빠른 테스트: 폴더당 3장

# %%
class_10_json = load_json(MMAD_CLASS_JSON)

# AD + LLM
# !python scripts/run_experiment.py \
    --llm {LLM} \
    --ad-model "patchcore" \
    --sample-per-folder {SAMPLE_PER_FOLDER} \
    --data-root {DATA_ROOT} \
    --output-dir {OUTPUT_AD} \
    --mmad-json {MMAD_CLASS_JSON} \
    --batch-mode true
# Out:
# Stratified sampling: 3장/폴더, 33폴더
#   Total: 4224 -> Sampled: 99 (normal=30, anomaly=69)
# ============================================================
# MMAD Experiment Runner
# ============================================================
# Experiment:  patchcore_gemma3-27b-int4_1shot
# LLM:         gemma3-27b-int4
# AD model:    patchcore
# RAG:         disabled
# Few-shot:    1
# Template:    Random_template
# Image size:  (384, 384)
# Images:      99 / 4224
# Data root:   /content/drive/Othercomputers/Mac/multiModal_anomaly_report/dataset/MMAD
# Output:      output/gemma3-27b-int4/rag/AD/answers_1_shot_gemma3-27b-int4_Random_template_with_patchcore_v0_99img.json
# ============================================================
#
# Filtered MMAD json: 99 images -> output/gemma3-27b-int4/rag/AD/_sampled_mmad.json
#
# ============================================================
# Running AD Model Inference
# ============================================================
# Script:       /content/drive/Othercomputers/Mac/multiModal_anomaly_report/scripts/run_ad_inference.py
# Config:       configs/anomaly.yaml
# Checkpoint:   /content/drive/Othercomputers/Mac/multiModal_anomaly_report/dataset/MMAD/checkpoints/patchcore_384
# Version:      v0
# Data root:    /content/drive/Othercomputers/Mac/multiModal_anomaly_report/dataset/MMAD
# MMAD JSON:    output/gemma3-27b-int4/rag/AD/_sampled_mmad.json
# Output:       output/gemma3-27b-int4/rag/AD/patchcore_predictions.json
#
# Backend: ckpt
# Config: configs/anomaly.yaml
# Output format: report
# Context mode: v2
# Decision rules: configs/ad_policy.json
# Calibration: configs/ad_calibration.json
# Batch size: 8
# IO workers: 8
# Decode reduced: x1
# Save interval: 0
# Profile interval: 128
# Postprocess map: input
# AMP: True
# Keep model cache: False
# Version: v0
# Filters: datasets=['GoodsAD', 'MVTec-LOCO'] categories=['breakfast_box', 'juice_bottle', 'pushpins', 'screw_bag', 'cigarette_box', 'drink_bottle', 'drink_can', 'food_bottle', 'food_box', 'food_package']
# Input size: (384, 384)
# Device: cuda
#
# Loading MMAD data from: output/gemma3-27b-int4/rag/AD/_sampled_mmad.json
# Total images to process: 99
# Available models: 10
#   - GoodsAD/cigarette_box
#   - GoodsAD/drink_bottle
#   - GoodsAD/drink_can
#   - GoodsAD/food_bottle
#   - GoodsAD/food_box
#   - GoodsAD/food_package
#   - MVTec-LOCO/breakfast_box
#   - MVTec-LOCO/juice_bottle
#   - MVTec-LOCO/pushpins
#   - MVTec-LOCO/screw_bag
#
# ============================================================
# Running inference
# ============================================================
# Images to process: 99 across 10 categories
#
# [GoodsAD/cigarette_box] Loading model and processing 6 images...
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:213: Attribute 'pre_processor' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['pre_processor'])`.
#   [profile-tail] 6 imgs | read 24.2 ms/img | infer 129.2 ms/img | build 1.3 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.34/0.54 GB
#   Done: 6 images in 0.9s (155ms/img)
#
# [GoodsAD/drink_bottle] Loading model and processing 12 images...
#   [profile-tail] 12 imgs | read 20.5 ms/img | infer 143.8 ms/img | build 1.4 ms/img | save 0.0 ms/img | gpu alloc/reserved 1.07/1.24 GB
#   Done: 12 images in 2.0s (166ms/img)
#
# [GoodsAD/drink_can] Loading model and processing 12 images...
#   [profile-tail] 12 imgs | read 20.2 ms/img | infer 10.9 ms/img | build 1.4 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.41/12.91 GB
#   Done: 12 images in 0.4s (33ms/img)
#
# [GoodsAD/food_bottle] Loading model and processing 12 images...
#   [profile-tail] 12 imgs | read 18.9 ms/img | infer 94.6 ms/img | build 1.3 ms/img | save 0.0 ms/img | gpu alloc/reserved 1.44/34.96 GB
#   Done: 12 images in 1.4s (115ms/img)
#
# [GoodsAD/food_box] Loading model and processing 12 images...
#   [profile-tail] 12 imgs | read 20.8 ms/img | infer 16.4 ms/img | build 1.4 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.67/23.56 GB
#   Done: 12 images in 0.5s (39ms/img)
#
# [GoodsAD/food_package] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 23.5 ms/img | infer 39.7 ms/img | build 1.4 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.81/0.90 GB
#   Done: 9 images in 0.6s (65ms/img)
#
# [MVTec-LOCO/breakfast_box] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 24.2 ms/img | infer 15.9 ms/img | build 1.5 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.56/19.18 GB
#   Done: 9 images in 0.4s (42ms/img)
#
# [MVTec-LOCO/juice_bottle] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 14.9 ms/img | infer 13.9 ms/img | build 1.4 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.54/18.32 GB
#   Done: 9 images in 0.3s (30ms/img)
#
# [MVTec-LOCO/pushpins] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 19.5 ms/img | infer 16.8 ms/img | build 1.2 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.59/20.32 GB
#   Done: 9 images in 0.3s (38ms/img)
#
# [MVTec-LOCO/screw_bag] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 22.0 ms/img | infer 14.6 ms/img | build 1.8 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.58/19.66 GB
#   Done: 9 images in 0.3s (39ms/img)
#
# ============================================================
# Inference complete
# ============================================================
# Processed (this run): 99
# Skipped (no model): 0
# Errors: 0
# Total inference time: 4.87s
# Average: 49.2ms/img
# Output saved to: output/gemma3-27b-int4/rag/AD/patchcore_predictions.json
#
# Sample output:
# {
#   "context_version": "ad_context_v2",
#   "image_path": "GoodsAD/cigarette_box/test/good/003_001.jpg",
#   "dataset": "GoodsAD",
#   "category": "cigarette_box",
#   "backend": "ckpt",
#   "anomaly_score": 0.5305,
#   "model_is_anomaly": true,
#   "model_threshold": 0.5,
#   "decision": "normal",
#   "review_needed": false,
#   "decision_confidence": 1.0,
#   "decision_basis": {
#     "center_threshold": 0.5911,
#     "uncertainty_band": 0.02,
#     "score_delta": -0.0606,
#     "used_calibration": true
#   },
#   "class_key": "GoodsAD/cigarette_box",
#   "confidence": {
#     "level": "low",
#     "reliability": "high",
#     "reason": "Score near threshold neighborhood",
#     "reliability_reason": "Policy marks this class as high reliability. Calibrated AUROC=0.910."
#   },
#   "defect_location_raw": {
#     "has_defect": true,
#     "region": "center",
#     "bbox": [
#       1648,
#       461,
#       2242,
#       1930
#     ],
#     "center": [
#       0.648,
#       0.398
#     ],
#     "area_ratio": 0.0133,
#     "confidence": 0.5972
#   },
#   "defect_location": {
#     "has_defect": false,
#     "region": "none",
#     "bbox": null,
#     "center": null,
#     "area_ratio": 0.0,
#     "location_confidence": 0.8587
#   },
#   "use_location_for_report": false,
#   "report_guidance": {
#     "use_ad_for_anomaly_judgement": "high",
#     "use_ad_for_location": "high",
#     "ad_weight": 0.7,
#     "location_confidence": 0.8587,
#     "decision_confidence": 1.0,
#     "instruction": "AD evidence is strong for anomaly existence. Use location hints only if they are consistent with the image.",
#     "reason_codes": [
#       "STRONG_NORMAL_MARGIN"
#     ]
#   },
#   "reason_codes": [
#     "STRONG_NORMAL_MARGIN"
#   ],
#   "map_stats": {
#     "max": 0.5972,
#     "mean": 0.2891,
#     "std": 0.0794
#   }
# }
# Loaded 99 AD predictions
#
# Warming up model (pre-loading weights)...
# 2026-02-24 11:57:31.475153: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771934251.498025   15421 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771934251.505475   15421 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771934251.524622   15421 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771934251.524649   15421 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771934251.524652   15421 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771934251.524655   15421 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Device: NVIDIA A100-SXM4-40GB
# Loading checkpoint shards: 100% 4/4 [00:06<00:00,  1.58s/it]
# Model ready.
#
# Evaluating:  66%|███████████████▊        | 65/99 [08:20<03:02,  5.36s/it, acc=71.3%, done=65, err=0]

# %%
# With RAG: Only Dense
# !python scripts/run_experiment.py \
    --llm {LLM} \
    --ad-model "patchcore" \
    --rag --rag-mode dense \
    --sample-per-folder {SAMPLE_PER_FOLDER} \
    --data-root {DATA_ROOT} \
    --output-dir {OUTPUT_ORIGIN} \
    --mmad-json {MMAD_CLASS_JSON} \
    --batch-mode true
# Out:
# Stratified sampling: 3장/폴더, 33폴더
#   Total: 4224 -> Sampled: 99 (normal=30, anomaly=69)
# 2026-02-24 11:10:47.146702: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771931447.169457    2734 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771931447.177045    2734 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771931447.196122    2734 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771931447.196146    2734 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771931447.196149    2734 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771931447.196152    2734 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# RAG enabled: 146 documents indexed (mode=dense)
# ============================================================
# MMAD Experiment Runner
# ============================================================
# Experiment:  patchcore_gemma3-27b-int4_1shot_rag_dense
# LLM:         gemma3-27b-int4
# AD model:    patchcore
# RAG:         enabled
# Few-shot:    1
# Template:    Random_template
# Image size:  (384, 384)
# Images:      99 / 4224
# Data root:   /content/drive/Othercomputers/Mac/multiModal_anomaly_report/dataset/MMAD
# Output:      output/gemma3-27b-int4/rag/original/answers_1_shot_gemma3-27b-int4_Random_template_with_patchcore_v0_rag_dense_99img.json
# ============================================================
#
# Filtered MMAD json: 99 images -> output/gemma3-27b-int4/rag/original/_sampled_mmad.json
#
# ============================================================
# Running AD Model Inference
# ============================================================
# Script:       /content/drive/Othercomputers/Mac/multiModal_anomaly_report/scripts/run_ad_inference.py
# Config:       configs/anomaly.yaml
# Checkpoint:   /content/drive/Othercomputers/Mac/multiModal_anomaly_report/dataset/MMAD/checkpoints/patchcore_384
# Version:      v0
# Data root:    /content/drive/Othercomputers/Mac/multiModal_anomaly_report/dataset/MMAD
# MMAD JSON:    output/gemma3-27b-int4/rag/original/_sampled_mmad.json
# Output:       output/gemma3-27b-int4/rag/original/patchcore_predictions.json
#
# Backend: ckpt
# Config: configs/anomaly.yaml
# Output format: report
# Context mode: v2
# Decision rules: configs/ad_policy.json
# Calibration: configs/ad_calibration.json
# Batch size: 8
# IO workers: 8
# Decode reduced: x1
# Save interval: 0
# Profile interval: 128
# Postprocess map: input
# AMP: True
# Keep model cache: False
# Version: v0
# Filters: datasets=['GoodsAD', 'MVTec-LOCO'] categories=['breakfast_box', 'juice_bottle', 'pushpins', 'screw_bag', 'cigarette_box', 'drink_bottle', 'drink_can', 'food_bottle', 'food_box', 'food_package']
# Input size: (384, 384)
# Device: cuda
#
# Loading MMAD data from: output/gemma3-27b-int4/rag/original/_sampled_mmad.json
# Total images to process: 99
# Available models: 10
#   - GoodsAD/cigarette_box
#   - GoodsAD/drink_bottle
#   - GoodsAD/drink_can
#   - GoodsAD/food_bottle
#   - GoodsAD/food_box
#   - GoodsAD/food_package
#   - MVTec-LOCO/breakfast_box
#   - MVTec-LOCO/juice_bottle
#   - MVTec-LOCO/pushpins
#   - MVTec-LOCO/screw_bag
#
# ============================================================
# Running inference
# ============================================================
# Images to process: 99 across 10 categories
#
# [GoodsAD/cigarette_box] Loading model and processing 6 images...
# /usr/local/lib/python3.12/dist-packages/FrEIA/modules/all_in_one_block.py:66: SyntaxWarning: invalid escape sequence '\m'
#   Initial value for the global affine scaling :math:`s_\mathrm{global}`.
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:213: Attribute 'pre_processor' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['pre_processor'])`.
#   [profile-tail] 6 imgs | read 800.6 ms/img | infer 167.1 ms/img | build 1.3 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.34/0.54 GB
#   Done: 6 images in 5.8s (969ms/img)
#
# [GoodsAD/drink_bottle] Loading model and processing 12 images...
#   [profile-tail] 12 imgs | read 905.1 ms/img | infer 147.2 ms/img | build 1.4 ms/img | save 0.0 ms/img | gpu alloc/reserved 1.07/1.24 GB
#   Done: 12 images in 12.6s (1054ms/img)
#
# [GoodsAD/drink_can] Loading model and processing 12 images...
#   [profile-tail] 12 imgs | read 557.4 ms/img | infer 10.7 ms/img | build 1.5 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.41/12.91 GB
#   Done: 12 images in 6.8s (570ms/img)
#
# [GoodsAD/food_bottle] Loading model and processing 12 images...
#   [profile-tail] 12 imgs | read 728.5 ms/img | infer 99.7 ms/img | build 1.3 ms/img | save 0.0 ms/img | gpu alloc/reserved 1.44/34.96 GB
#   Done: 12 images in 10.0s (830ms/img)
#
# [GoodsAD/food_box] Loading model and processing 12 images...
#   [profile-tail] 12 imgs | read 662.9 ms/img | infer 17.5 ms/img | build 1.3 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.67/23.56 GB
#   Done: 12 images in 8.2s (682ms/img)
#
# [GoodsAD/food_package] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 926.0 ms/img | infer 44.4 ms/img | build 1.4 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.81/0.90 GB
#   Done: 9 images in 8.7s (972ms/img)
#
# [MVTec-LOCO/breakfast_box] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 559.7 ms/img | infer 19.2 ms/img | build 1.4 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.56/19.18 GB
#   Done: 9 images in 5.2s (581ms/img)
#
# [MVTec-LOCO/juice_bottle] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 676.5 ms/img | infer 14.0 ms/img | build 1.4 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.54/18.32 GB
#   Done: 9 images in 6.2s (692ms/img)
#
# [MVTec-LOCO/pushpins] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 879.4 ms/img | infer 16.7 ms/img | build 1.2 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.59/20.32 GB
#   Done: 9 images in 8.1s (897ms/img)
#
# [MVTec-LOCO/screw_bag] Loading model and processing 9 images...
#   [profile-tail] 9 imgs | read 550.6 ms/img | infer 14.7 ms/img | build 1.8 ms/img | save 0.0 ms/img | gpu alloc/reserved 0.58/19.66 GB
#   Done: 9 images in 5.1s (567ms/img)
#
# ============================================================
# Inference complete
# ============================================================
# Processed (this run): 99
# Skipped (no model): 0
# Errors: 0
# Total inference time: 5.29s
# Average: 53.4ms/img
# Output saved to: output/gemma3-27b-int4/rag/original/patchcore_predictions.json
#
# Sample output:
# {
#   "context_version": "ad_context_v2",
#   "image_path": "GoodsAD/cigarette_box/test/good/003_001.jpg",
#   "dataset": "GoodsAD",
#   "category": "cigarette_box",
#   "backend": "ckpt",
#   "anomaly_score": 0.5305,
#   "model_is_anomaly": true,
#   "model_threshold": 0.5,
#   "decision": "normal",
#   "review_needed": false,
#   "decision_confidence": 1.0,
#   "decision_basis": {
#     "center_threshold": 0.5911,
#     "uncertainty_band": 0.02,
#     "score_delta": -0.0606,
#     "used_calibration": true
#   },
#   "class_key": "GoodsAD/cigarette_box",
#   "confidence": {
#     "level": "low",
#     "reliability": "high",
#     "reason": "Score near threshold neighborhood",
#     "reliability_reason": "Policy marks this class as high reliability. Calibrated AUROC=0.910."
#   },
#   "defect_location_raw": {
#     "has_defect": true,
#     "region": "center",
#     "bbox": [
#       1648,
#       461,
#       2242,
#       1930
#     ],
#     "center": [
#       0.648,
#       0.398
#     ],
#     "area_ratio": 0.0132,
#     "confidence": 0.5972
#   },
#   "defect_location": {
#     "has_defect": false,
#     "region": "none",
#     "bbox": null,
#     "center": null,
#     "area_ratio": 0.0,
#     "location_confidence": 0.8587
#   },
#   "use_location_for_report": false,
#   "report_guidance": {
#     "use_ad_for_anomaly_judgement": "high",
#     "use_ad_for_location": "high",
#     "ad_weight": 0.7,
#     "location_confidence": 0.8587,
#     "decision_confidence": 1.0,
#     "instruction": "AD evidence is strong for anomaly existence. Use location hints only if they are consistent with the image.",
#     "reason_codes": [
#       "STRONG_NORMAL_MARGIN"
#     ]
#   },
#   "reason_codes": [
#     "STRONG_NORMAL_MARGIN"
#   ],
#   "map_stats": {
#     "max": 0.5972,
#     "mean": 0.2891,
#     "std": 0.0794
#   }
# }
# Loaded 99 AD predictions
#
# Warming up model (pre-loading weights)...
# Device: NVIDIA A100-SXM4-40GB
# config.json: 4.11kB [00:00, 15.7MB/s]
# pytorch_model.bin.index.json: 127kB [00:00, 346MB/s]
# Fetching 4 files:   0% 0/4 [00:00<?, ?it/s]
# pytorch_model-00001-of-00004.bin:   0% 0.00/4.99G [00:00<?, ?B/s]
#
# pytorch_model-00003-of-00004.bin:   0% 0.00/4.98G [00:00<?, ?B/s]
#
#
# pytorch_model-00002-of-00004.bin:   0% 0.00/4.98G [00:00<?, ?B/s]
#
#
#
# pytorch_model-00004-of-00004.bin:   0% 0.00/3.33G [00:00<?, ?B/s]
#
#
#
# pytorch_model-00004-of-00004.bin:   0% 786k/3.33G [00:01<1:18:06, 709kB/s]
#
#
#
# pytorch_model-00004-of-00004.bin:   0% 2.36M/3.33G [00:01<24:02, 2.30MB/s]
#
# pytorch_model-00003-of-00004.bin:   0% 1.18M/4.98G [00:01<1:39:42, 832kB/s]
#
#
# pytorch_model-00002-of-00004.bin:   0% 1.18M/4.98G [00:01<1:39:26, 834kB/s]
#
# pytorch_model-00003-of-00004.bin:   1% 69.0M/4.98G [00:01<01:21, 60.0MB/s]
#
# pytorch_model-00003-of-00004.bin:   3% 136M/4.98G [00:01<00:39, 123MB/s]
#
#
# pytorch_model-00002-of-00004.bin:   0% 4.46M/4.98G [00:01<26:31, 3.12MB/s]
#
# pytorch_model-00003-of-00004.bin:   8% 402M/4.98G [00:01<00:11, 393MB/s]
# pytorch_model-00001-of-00004.bin:   0% 1.06M/4.99G [00:01<2:35:08, 536kB/s]
#
#
# pytorch_model-00002-of-00004.bin:   1% 71.5M/4.98G [00:02<01:27, 55.9MB/s]
#
# pytorch_model-00003-of-00004.bin:  12% 604M/4.98G [00:02<00:07, 567MB/s]
#
#
#
# pytorch_model-00004-of-00004.bin:   0% 3.80M/3.33G [00:02<27:40, 2.00MB/s]
# pytorch_model-00001-of-00004.bin:   0% 3.22M/4.99G [00:02<46:39, 1.78MB/s]
#
#
# pytorch_model-00002-of-00004.bin:   5% 273M/4.98G [00:02<00:20, 234MB/s]
# pytorch_model-00001-of-00004.bin:   0% 13.1M/4.99G [00:02<08:51, 9.37MB/s]
#
#
# pytorch_model-00002-of-00004.bin:   7% 340M/4.98G [00:02<00:16, 281MB/s]
#
#
#
# pytorch_model-00004-of-00004.bin:   0% 4.59M/3.33G [00:02<26:20, 2.10MB/s]
#
#
# pytorch_model-00002-of-00004.bin:  10% 474M/4.98G [00:02<00:11, 399MB/s]
# pytorch_model-00001-of-00004.bin:   0% 19.4M/4.99G [00:02<06:44, 12.3MB/s]
#
#
# pytorch_model-00002-of-00004.bin:  11% 541M/4.98G [00:02<00:10, 433MB/s]
#
# pytorch_model-00003-of-00004.bin:  18% 877M/4.98G [00:02<00:08, 478MB/s]
#
#
# pytorch_model-00002-of-00004.bin:  14% 675M/4.98G [00:02<00:09, 463MB/s]
#
#
# pytorch_model-00002-of-00004.bin:  16% 807M/4.98G [00:03<00:07, 570MB/s]
#
# pytorch_model-00003-of-00004.bin:  20% 1.01G/4.98G [00:03<00:08, 469MB/s]
#
#
#
# pytorch_model-00004-of-00004.bin
# pytorch_model-00001-of-00004.bin:  85% 4.26G/4.99G [00:53<00:01, 507MB/s]
# pytorch_model-00001-of-00004.bin:  88% 4.39G/4.99G [00:53<00:01, 550MB/s]
# pytorch_model-00001-of-00004.bin:  91% 4.52G/4.99G [00:53<00:00, 476MB/s]
# pytorch_model-00001-of-00004.bin:  92% 4.59G/4.99G [00:53<00:00, 474MB/s]
# pytorch_model-00001-of-00004.bin:  93% 4.66G/4.99G [00:55<00:01, 172MB/s]
# pytorch_model-00001-of-00004.bin:  95% 4.73G/4.99G [00:55<00:01, 182MB/s]
# pytorch_model-00001-of-00004.bin:  96% 4.79G/4.99G [00:55<00:01, 169MB/s]
# pytorch_model-00001-of-00004.bin:  97% 4.86G/4.99G [00:56<00:01, 121MB/s]
# pytorch_model-00001-of-00004.bin: 100% 4.99G/4.99G [00:57<00:00, 87.6MB/s]
# Fetching 4 files: 100% 4/4 [00:57<00:00, 14.33s/it]
# Loading checkpoint shards: 100% 4/4 [00:05<00:00,  1.49s/it]
# generation_config.json: 100% 210/210 [00:00<00:00, 1.79MB/s]
# processor_config.json: 100% 70.0/70.0 [00:00<00:00, 702kB/s]
# chat_template.jinja: 1.53kB [00:00, 7.02MB/s]
# preprocessor_config.json: 100% 570/570 [00:00<00:00, 5.96MB/s]
# tokenizer_config.json: 1.16MB [00:00, 600MB/s]
# tokenizer.model: 100% 4.69M/4.69M [00:00<00:00, 17.2MB/s]
# tokenizer.json: 100% 33.4M/33.4M [00:00<00:00, 94.0MB/s]
# added_tokens.json: 100% 35.0/35.0 [00:00<00:00, 337kB/s]
# special_tokens_map.json: 100% 662/662 [00:00<00:00, 6.99MB/s]
# Model ready.
#
# Evaluating: 100%|████████████████████████| 99/99 [19:01<00:00, 11.53s/it, acc=75.1%, done=99, err=0]
#
# ============================================================
# Latency by Class
# ============================================================
#   Class                               N   Avg(s)   Total(s)
# ------------------------------------------------------------
#   GoodsAD/cigarette_box               6    53.62     321.75
#   GoodsAD/drink_bottle               12     7.80      93.62
#   GoodsAD/drink_can                  12     7.50      89.99
#   GoodsAD/food_bottle                12     8.32      99.78
#   GoodsAD/food_box                   12     8.50     101.97
#   GoodsAD/food_package                9    14.82     133.38
#   MVTec-LOCO/breakfast_box            9     8.18      73.66
#   MVTec-LOCO/juice_bottle             9     8.58      77.20
#   MVTec-LOCO/pushpins                 9     7.76      69.88
#   MVTec-LOCO/screw_bag                9     8.56      77.06
# ------------------------------------------------------------
#   Overall                            99    11.53     1141.2
#
#
# ============================================================
# Calculating Metrics
# ============================================================
#
# === Accuracy Statistics for answers_1_shot_gemma3-27b-int4_Random_template_with_patchcore_v0_rag_dense_99img.json ===
#
#             Anomaly Detection  Object Classification  Object Analysis  Defect Classification  Defect Localization  Defect Description  Defect Analysis     Recall  Precision         F1    Average
# GoodsAD             63.594771                   80.0        77.777778              73.529412            52.380952           82.857143        74.418605  97.777778  78.571429  87.128713  72.079809
# MVTec-LOCO          77.083333                  100.0        77.142857              70.833333            60.869565           69.565217        85.714286  95.833333  82.142857  88.461538  77.315513
# Average             70.339052                   90.0        77.460317              72.181373            56.625259           76.211180        80.066445  96.805556  80.357143  87.795126  74.697661
#
# === Overall Average ===
# Anomaly Detection        70.339052
# Object Classification    90.000000
# Object Analysis          77.460317
# Defect Classification    72.181373
# Defect Localization      56.625259
# Defect Description       76.211180
# Defect Analysis          80.066445
# Recall                   96.805556
# Precision                80.357143
# F1                       87.795126
# Average                  74.697661
# Name: Average, dtype: float64
#
# Saved accuracy CSV to: output/gemma3-27b-int4/rag/original/answers_1_shot_gemma3-27b-int4_Random_template_with_patchcore_v0_rag_dense_99img_accuracy.csv
#
# Results saved to: output/gemma3-27b-int4/rag/original/answers_1_shot_gemma3-27b-int4_Random_template_with_patchcore_v0_rag_dense_99img.json
# Metadata saved to: output/gemma3-27b-int4/rag/original/answers_1_shot_gemma3-27b-int4_Random_template_with_patchcore_v0_rag_dense_99img.meta.json
# Elapsed: 1141.2s

# %%
# With RAG: Hybrid
# !python scripts/run_experiment.py \
    --llm {LLM} \
    --ad-model "patchcore" \
    --rag --rag-mode hybrid \
    --sample-per-folder {SAMPLE_PER_FOLDER} \
    --data-root {DATA_ROOT} \
    --output-dir {OUTPUT_ORIGIN} \
    --mmad-json {MMAD_CLASS_JSON} \
    --batch-mode true

# %%
# # With RAG
# LLM = "gemini-2.5-flash-lite"
# !python scripts/run_experiment.py \
#     --llm {LLM} \
#     --ad-model "patchcore" \
#     --rag \
#     --data-root {DATA_ROOT} \
#     --output-dir {OUTPUT_ORIGIN} \
#     --mmad-json {MMAD_CLASS_JSON} \
#     --batch-mode true

# %%
# # 결과 비교
# configs = {
#     # "Baseline": OUTPUT_DIR,
#     # "AD only": OUTPUT_AD,
#     "AD+RAG": OUTPUT_ORIGIN,
#     "AD+RAG (+PDF)": OUTPUT_PDF,
# }

# def load_latest_meta(output_dir):
#     files = sorted(Path(output_dir).glob("*.meta.json"))
#     if not files:
#         return None
#     return json.load(open(files[-1]))

# rows = {}
# for label, out_dir in configs.items():
#     meta = load_latest_meta(out_dir)
#     rows[label] = meta

# # 기준: Baseline accuracy
# # bl_acc = rows["Baseline"]["accuracy"] if rows["Baseline"] else 0

# print(f"{'Config':<12} {'Accuracy':>10} {'Correct':>9} {'Total':>7} {'Diff':>8}")
# print("=" * 52)
# for label, meta in rows.items():
#     if meta is None:
#         print(f"{label:<12} {'결과없음':>10}")
#         continue
#     acc  = meta.get("accuracy", 0)
#     cor  = meta.get("total_correct", 0)
#     tot  = meta.get("total_questions", 0)
#     # diff = acc - bl_acc
#     # sign = "+" if diff > 0 else ""
#     # diff_str = f"{sign}{diff:.2f}" if label != "Baseline" else "-"
#     print(f"{label:<12} {acc:>9.2f}% {cor:>9} {tot:>7}") # {diff_str:>8}

# def load_latest_answers(output_dir):
#     files = [f for f in sorted(Path(output_dir).glob("answers_*.json")) if ".meta." not in f.name]
#     return json.load(open(files[-1])) if files else []

# answers = {label: load_latest_answers(d) for label, d in configs.items()}

# # good vs anomaly 정확도
# print(f"{'Config':<25} {'good':>8} {'anomaly':>10}")
# print("-" * 46)
# for label, ans in answers.items():
#     good    = [a for a in ans if "/good/" in a["image"]]
#     anomaly = [a for a in ans if "/good/" not in a["image"]]
#     g_acc = sum(a["gpt_answer"]==a["correct_answer"] for a in good) / len(good) * 100 if good else 0
#     a_acc = sum(a["gpt_answer"]==a["correct_answer"] for a in anomaly) / len(anomaly) * 100 if anomaly else 0
#     print(f"{label:<25} {g_acc:>7.1f}% {a_acc:>9.1f}%")
